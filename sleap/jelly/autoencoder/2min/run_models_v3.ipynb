# %%
from run_models import *

# %% [markdown]
# ## m10

# %% [markdown]
# ### t1

# %%
prediction_m10t1 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(5e-4), num_layers=5, 
                              window_size=30,
                              dropout_rate=0, swap_rate=0)
print(prediction_m10t1.shape)
np.save('../results/r3/prediction_m10t1.npy', prediction_m10t1)
# Out:
# 2001 windows have no valid points
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 30, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 30, 34)      1020        ['input_1[0][0]']
#   (LearnablePositionalEncoding2
#  )
#
#  multi_head_attention (MultiHea  (None, 30, 34)      35618       ['learnable_positional_encoding2[
#  dAttention)                                                     0][0]',
#                                                                   'learnable_positional_encoding2[
#                                                                  0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 30, 34)      0           ['learnable_positional_encoding2[
#  da)                                                             0][0]',
# ...

# %% [markdown]
# ### t2

# %%
prediction_m10t2 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(1e-3), num_layers=5, 
                              window_size=30,
                              dropout_rate=0, swap_rate=0)
print(prediction_m10t2.shape)
np.save('../results/r3/prediction_m10t2.npy', prediction_m10t2)
# Out:
# 0 windows have no valid points
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 30, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 30, 34)      1020        ['input_2[0][0]']
#  _1 (LearnablePositionalEncodin
#  g2)
#
#  multi_head_attention_5 (MultiH  (None, 30, 34)      35618       ['learnable_positional_encoding2_
#  eadAttention)                                                   1[0][0]',
#                                                                   'learnable_positional_encoding2_
#                                                                  1[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 30, 34)      0           ['learnable_positional_encoding2_
#  ambda)                                                          1[0][0]',
# ...

# %% [markdown]
# ### t3

# %%
prediction_m10t3 = run_model_10(epochs=200, batch_size=32, optimizer=Adam(1e-4), num_layers=5, 
                              window_size=30,
                              dropout_rate=0, swap_rate=0)
print(prediction_m10t3.shape)
np.save('../results/r3/prediction_m10t3.npy', prediction_m10t3)
# Out:
# 0 windows have no valid points
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 30, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 30, 34)      1020        ['input_2[0][0]']
#  _1 (LearnablePositionalEncodin
#  g2)
#
#  multi_head_attention_5 (MultiH  (None, 30, 34)      35618       ['learnable_positional_encoding2_
#  eadAttention)                                                   1[0][0]',
#                                                                   'learnable_positional_encoding2_
#                                                                  1[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 30, 34)      0           ['learnable_positional_encoding2_
#  ambda)                                                          1[0][0]',
# ...
