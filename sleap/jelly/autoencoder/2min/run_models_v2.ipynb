# %%
from run_models import *
# Out:
# 2025-02-12 16:02:42.689630: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-12 16:02:42.733310: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739404962.774258 1632136 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739404962.787010 1632136 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-12 16:02:42.824704: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## m1

# %%
prediction_m1t1 = run_model_1(epochs=200, batch_size=32, optimizer=Adam(1e-4))
print(prediction_m1t1.shape)
np.save('../results/r2/prediction_m1t1.npy', prediction_m1t1)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 5, 34)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 5, 64)          │        25,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector_1 (RepeatVector)  │ (None, 5, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 5, 32)          │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 5, 64)          │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 5, 34)          │         2,210 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73,122 (285.63 KB)
#  Trainable params: 73,122 (285.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 5, 34)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 5, 64)          │        25,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector_1 (RepeatVector)  │ (None, 5, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 5, 32)          │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 5, 64)          │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 5, 34)          │         2,210 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73,122 (285.63 KB)
#  Trainable params: 73,122 (285.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - loss: 1.4453 - val_loss: 0.9424
# Epoch 2/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.7300 - val_loss: 0.5447
# Epoch 3/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.4825 - val_loss: 0.4522
# Epoch 4/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.4057 - val_loss: 0.4098
# Epoch 5/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3741 - val_loss: 0.3795
# Epoch 6/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3334 - val_loss: 0.3541
# Epoch 7/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3156 - val_loss: 0.3329
# Epoch 8/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3013 - val_loss: 0.3166
# Epoch 9/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2778 - val_loss: 0.2992
# Epoch 10/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2620 - val_loss: 0.2853
# Epoch 11/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2478 - val_loss: 0.2773
# Epoch 12/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2479 - val_loss: 0.2627
# Epoch 13/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2305 - val_loss: 0.2587
# Epoch 14/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2268 - val_loss: 0.2480
# Epoch 15/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2231 - val_loss: 0.2390
# Epoch 16/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2086 - val_loss: 0.2321
# Epoch 17/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2095 - val_loss: 0.2259
# Epoch 18/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2029 - val_loss: 0.2212
# Epoch 19/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1958 - val_loss: 0.2195
# Epoch 20/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1948 - val_loss: 0.2110
# Epoch 21/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1832 - val_loss: 0.2062
# Epoch 22/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1821 - val_loss: 0.2043
# Epoch 23/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1801 - val_loss: 0.2007
# Epoch 24/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1740 - val_loss: 0.1941
# Epoch 25/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1701 - val_loss: 0.1915
# Epoch 26/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1697 - val_loss: 0.1883
# Epoch 27/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1664 - val_loss: 0.1869
# Epoch 28/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1631 - val_loss: 0.1806
# Epoch 29/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1589 - val_loss: 0.1791
# Epoch 30/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1585 - val_loss: 0.1749
# Epoch 31/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1585 - val_loss: 0.1753
# Epoch 32/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1543 - val_loss: 0.1716
# Epoch 33/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1498 - val_loss: 0.1697
# Epoch 34/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1463 - val_loss: 0.1677
# Epoch 35/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1480 - val_loss: 0.1642
# Epoch 36/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1471 - val_loss: 0.1622
# Epoch 37/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1399 - val_loss: 0.1609
# Epoch 38/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1425 - val_loss: 0.1602
# Epoch 39/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1378 - val_loss: 0.1578
# Epoch 40/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1335 - val_loss: 0.1560
# Epoch 41/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1362 - val_loss: 0.1569
# Epoch 42/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1367 - val_loss: 0.1526
# Epoch 43/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1342 - val_loss: 0.1515
# Epoch 44/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1328 - val_loss: 0.1517
# Epoch 45/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1271 - val_loss: 0.1526
# Epoch 46/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1310 - val_loss: 0.1488
# Epoch 47/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1292 - val_loss: 0.1457
# Epoch 48/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1305 - val_loss: 0.1461
# Epoch 49/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1293 - val_loss: 0.1442
# Epoch 50/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1244 - val_loss: 0.1435
# Epoch 51/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1288 - val_loss: 0.1436
# Epoch 52/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1231 - val_loss: 0.1419
# Epoch 53/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1234 - val_loss: 0.1428
# Epoch 54/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1221 - val_loss: 0.1393
# Epoch 55/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1206 - val_loss: 0.1397
# Epoch 56/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1198 - val_loss: 0.1383
# Epoch 57/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1192 - val_loss: 0.1371
# Epoch 58/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1178 - val_loss: 0.1371
# Epoch 59/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1181 - val_loss: 0.1394
# Epoch 60/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1217 - val_loss: 0.1358
# Epoch 61/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1161 - val_loss: 0.1344
# Epoch 62/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1144 - val_loss: 0.1354
# Epoch 63/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1137 - val_loss: 0.1329
# Epoch 64/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1156 - val_loss: 0.1344
# Epoch 65/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1151 - val_loss: 0.1320
# Epoch 66/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1150 - val_loss: 0.1329
# Epoch 67/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1142 - val_loss: 0.1323
# Epoch 68/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1123 - val_loss: 0.1306
# Epoch 69/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1098 - val_loss: 0.1299
# Epoch 70/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1123 - val_loss: 0.1294
# Epoch 71/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1111 - val_loss: 0.1297
# Epoch 72/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1142 - val_loss: 0.1297
# Epoch 73/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1065 - val_loss: 0.1282
# Epoch 74/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1079 - val_loss: 0.1274
# Epoch 75/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1084 - val_loss: 0.1266
# Epoch 76/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1099 - val_loss: 0.1260
# Epoch 77/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1110 - val_loss: 0.1265
# Epoch 78/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1068 - val_loss: 0.1266
# Epoch 79/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1075 - val_loss: 0.1243
# Epoch 80/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1096 - val_loss: 0.1247
# Epoch 81/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1077 - val_loss: 0.1257
# Epoch 82/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1047 - val_loss: 0.1485
# Epoch 83/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1153 - val_loss: 0.1249
# Epoch 84/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1051 - val_loss: 0.1235
# Epoch 85/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1035 - val_loss: 0.1241
# Epoch 86/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1079 - val_loss: 0.1217
# Epoch 87/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1035 - val_loss: 0.1233
# Epoch 88/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1050 - val_loss: 0.1204
# Epoch 89/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1035 - val_loss: 0.1221
# Epoch 90/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1047 - val_loss: 0.1224
# Epoch 91/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1038 - val_loss: 0.1201
# Epoch 92/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1024 - val_loss: 0.1202
# Epoch 93/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1030 - val_loss: 0.1200
# Epoch 94/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1016 - val_loss: 0.1215
# Epoch 95/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1019 - val_loss: 0.1187
# Epoch 96/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1018 - val_loss: 0.1185
# Epoch 97/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1027 - val_loss: 0.1177
# Epoch 98/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1015 - val_loss: 0.1178
# Epoch 99/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1012 - val_loss: 0.1191
# Epoch 100/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1015 - val_loss: 0.1186
# Epoch 101/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1008 - val_loss: 0.1181
# Epoch 102/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0980 - val_loss: 0.1175
# Epoch 103/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1009 - val_loss: 0.1179
# Epoch 104/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0997 - val_loss: 0.1177
# Epoch 105/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0997 - val_loss: 0.1176
# Epoch 106/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0992 - val_loss: 0.1163
# Epoch 107/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0995 - val_loss: 0.1156
# Epoch 108/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0975 - val_loss: 0.1160
# Epoch 109/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1005 - val_loss: 0.1151
# Epoch 110/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0955 - val_loss: 0.1164
# Epoch 111/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0989 - val_loss: 0.1147
# Epoch 112/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0979 - val_loss: 0.1138
# Epoch 113/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1000 - val_loss: 0.1147
# Epoch 114/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0995 - val_loss: 0.1182
# Epoch 115/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0976 - val_loss: 0.1143
# Epoch 116/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0968 - val_loss: 0.1128
# Epoch 117/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0937 - val_loss: 0.1125
# Epoch 118/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0949 - val_loss: 0.1126
# Epoch 119/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0941 - val_loss: 0.1132
# Epoch 120/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0948 - val_loss: 0.1125
# Epoch 121/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0948 - val_loss: 0.1137
# Epoch 122/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0928 - val_loss: 0.1122
# Epoch 123/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0957 - val_loss: 0.1131
# Epoch 124/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0932 - val_loss: 0.1108
# Epoch 125/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0926 - val_loss: 0.1110
# Epoch 126/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0931 - val_loss: 0.1111
# Epoch 127/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0949 - val_loss: 0.1120
# Epoch 128/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0934 - val_loss: 0.1101
# Epoch 129/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0974 - val_loss: 0.1104
# Epoch 130/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0951 - val_loss: 0.1108
# Epoch 131/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0932 - val_loss: 0.1104
# Epoch 132/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0948 - val_loss: 0.1090
# Epoch 133/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0932 - val_loss: 0.1094
# Epoch 134/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0902 - val_loss: 0.1096
# Epoch 135/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0907 - val_loss: 0.1108
# Epoch 136/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0917 - val_loss: 0.1093
# Epoch 137/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0927 - val_loss: 0.1089
# Epoch 138/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0916 - val_loss: 0.1104
# Epoch 139/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0955 - val_loss: 0.1086
# Epoch 140/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0906 - val_loss: 0.1070
# Epoch 141/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0934 - val_loss: 0.1073
# Epoch 142/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0904 - val_loss: 0.1068
# Epoch 143/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0921 - val_loss: 0.1076
# Epoch 144/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0891 - val_loss: 0.1076
# Epoch 145/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0927 - val_loss: 0.1069
# Epoch 146/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0888 - val_loss: 0.1065
# Epoch 147/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0932 - val_loss: 0.1061
# Epoch 148/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0906 - val_loss: 0.1058
# Epoch 149/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0885 - val_loss: 0.1064
# Epoch 150/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0906 - val_loss: 0.1058
# Epoch 151/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0931 - val_loss: 0.1047
# Epoch 152/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0917 - val_loss: 0.1056
# Epoch 153/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0905 - val_loss: 0.1055
# Epoch 154/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0862 - val_loss: 0.1051
# Epoch 155/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0900 - val_loss: 0.1050
# Epoch 156/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0912 - val_loss: 0.1057
# Epoch 157/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0878 - val_loss: 0.1070
# Epoch 158/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0888 - val_loss: 0.1041
# Epoch 159/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0904 - val_loss: 0.1048
# Epoch 160/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0865 - val_loss: 0.1046
# Epoch 161/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0893 - val_loss: 0.1062
# Epoch 162/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0897 - val_loss: 0.1038
# Epoch 163/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0877 - val_loss: 0.1045
# Epoch 164/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0878 - val_loss: 0.1026
# Epoch 165/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0848 - val_loss: 0.1033
# Epoch 166/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0878 - val_loss: 0.1035
# Epoch 167/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0860 - val_loss: 0.1036
# Epoch 168/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0878 - val_loss: 0.1026
# Epoch 169/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0882 - val_loss: 0.1033
# Epoch 170/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0855 - val_loss: 0.1028
# Epoch 171/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0856 - val_loss: 0.1021
# Epoch 172/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0877 - val_loss: 0.1016
# Epoch 173/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0859 - val_loss: 0.1021
# Epoch 174/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0877 - val_loss: 0.1015
# Epoch 175/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0843 - val_loss: 0.1055
# Epoch 176/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0877 - val_loss: 0.1026
# Epoch 177/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0862 - val_loss: 0.1021
# Epoch 178/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0891 - val_loss: 0.1020
# Epoch 179/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0856 - val_loss: 0.1014
# Epoch 180/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0858 - val_loss: 0.1019
# Epoch 181/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0862 - val_loss: 0.1034
# Epoch 182/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0850 - val_loss: 0.1016
# Epoch 183/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0827 - val_loss: 0.1002
# Epoch 184/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0844 - val_loss: 0.1009
# Epoch 185/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0848 - val_loss: 0.1003
# Epoch 186/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0855 - val_loss: 0.1013
# Epoch 187/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0861 - val_loss: 0.1010
# Epoch 188/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0849 - val_loss: 0.1007
# Epoch 189/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0839 - val_loss: 0.1007
# Epoch 190/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0865 - val_loss: 0.1005
# Epoch 191/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0843 - val_loss: 0.1009
# Epoch 192/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0833 - val_loss: 0.0990
# Epoch 193/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0837 - val_loss: 0.0998
# Epoch 194/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0844 - val_loss: 0.0991
# Epoch 195/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0853 - val_loss: 0.0988
# Epoch 196/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0826 - val_loss: 0.0983
# Epoch 197/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0849 - val_loss: 0.0991
# Epoch 198/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0849 - val_loss: 0.0987
# Epoch 199/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0829 - val_loss: 0.0999
# Epoch 200/200
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0844 - val_loss: 0.0985
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
# (9000, 17, 2)

# %% [markdown]
# ## m2

# %%
prediction_m2t1 = run_model_2(epochs=200, batch_size=32, optimizer=Adam(1e-4))
print(prediction_m2t1.shape)
np.save('../results/r2/prediction_m2t1.npy', prediction_m2t1)
# Out:
# Model: "temporal_autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_sequence (InputLayer)     │ (None, 5, 17, 2)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalize (Lambda)              │ (None, 5, 17, 2)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_per_frame               │ (None, 5, 34)          │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise (GaussianNoise)  │ (None, 5, 34)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_lstm (LSTM)             │ (None, 64)             │        25,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector (RepeatVector)    │ (None, 5, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_lstm (LSTM)             │ (None, 5, 64)          │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_dense          │ (None, 5, 34)          │         2,210 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_sequence                 │ (None, 5, 17, 2)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ denormalize (Lambda)            │ (None, 5, 17, 2)       │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 60,578 (236.63 KB)
#  Trainable params: 60,578 (236.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "temporal_autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_sequence (InputLayer)     │ (None, 5, 17, 2)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalize (Lambda)              │ (None, 5, 17, 2)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_per_frame               │ (None, 5, 34)          │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise (GaussianNoise)  │ (None, 5, 34)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_lstm (LSTM)             │ (None, 64)             │        25,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector (RepeatVector)    │ (None, 5, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_lstm (LSTM)             │ (None, 5, 64)          │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_dense          │ (None, 5, 34)          │         2,210 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_sequence                 │ (None, 5, 17, 2)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ denormalize (Lambda)            │ (None, 5, 17, 2)       │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 60,578 (236.63 KB)
#  Trainable params: 60,578 (236.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 prediction_m2t1 = run_model_2(epochs=200, batch_size=32, optimizer=Adam(1e-4))
#       2 print(prediction_m2t1.shape)
#       3 np.save('../results/r2/prediction_m2t1.npy', prediction_m2t1)
#
# File ~/Desktop/jelly-sleap/sleap/jelly/autoencoder/2min/run_models.py:63, in run_model_2(train_slice_only, window_size, epochs, batch_size, optimizer)
#      61 model.compile(optimizer=optimizer, loss=masked_mse_loss)
#      62 model.summary()
# ---> 63 model.fit(X_train, y_train,
#      64           epochs=epochs,
#      65           batch_size=batch_size,
#      66           validation_data=(X_val, y_val),
#      67           callbacks=[tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)])
#      69 denoised_windows = model.predict(X)
#      70 denoised_coords = reconstruct_full_sequence(denoised_windows)
#
# File ~/micromamba/envs/tf/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/micromamba/envs/tf/lib/python3.11/site-packages/keras/src/layers/input_spec.py:245, in assert_input_compatibility(input_spec, inputs, layer_name)
#     243 if spec_dim is not None and dim is not None:
#     244     if spec_dim != dim:
# --> 245         raise ValueError(
#     246             f'Input {input_index} of layer "{layer_name}" is '
#     247             "incompatible with the layer: "
#     248             f"expected shape={spec.shape}, "
#     249             f"found shape={shape}"
#     250         )
#
# ValueError: Input 0 of layer "temporal_autoencoder" is incompatible with the layer: expected shape=(None, 5, 17, 2), found shape=(None, 5, 34)

# %% [markdown]
# ## m3

# %%
prediction_m3t1 = run_model_3(epochs=100, batch_size=32, optimizer=Adam(1e-4))
print(prediction_m3t1.shape)
np.save('../results/r2/prediction_m3t1.npy', prediction_m3t1)

# %% [markdown]
# ## m4

# %%
prediction_m4t1 = run_model_4(epochs=100, batch_size=32, optimizer=Adam(1e-4))
print(prediction_m4t1.shape)
np.save('../results/r2/prediction_m4t1.npy', prediction_m4t1)

# %% [markdown]
# ## m5

# %%
prediction_m5t1 = run_model_5(epochs=100, batch_size=32, optimizer=Adam(1e-4))
print(prediction_m5t1.shape)
np.save('../results/r2/prediction_m5t1.npy', prediction_m5t1)
# Out:
# I0000 00:00:1739384395.140724  955698 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18436 MB memory:  -> device: 0, name: NVIDIA RTX A4500, pci bus id: 0000:17:00.0, compute capability: 8.6
# I0000 00:00:1739384395.141585  955698 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 18070 MB memory:  -> device: 1, name: NVIDIA RTX A4500, pci bus id: 0000:73:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 5, 34)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 5, 64)     │      6,592 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 5, 64)     │        128 │ conv1d[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 5, 128)    │     24,704 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 128)    │        256 │ conv1d_1[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 5, 256)    │     98,560 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 256)    │        512 │ conv1d_2[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 5, 256)    │     65,792 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 5, 256)    │          0 │ layer_normalizat… │
# │                     │                   │            │ conv1d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 5, 256)    │     65,792 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 5, 256)    │          0 │ multiply[0][0],   │
# │                     │                   │            │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 256)    │        512 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 5, 128)    │     98,432 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 128)    │        256 │ conv1d_5[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 5, 64)     │     24,640 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 64)     │        128 │ conv1d_6[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 5, 34)     │      6,562 │ layer_normalizat… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 392,866 (1.50 MB)
#  Trainable params: 392,866 (1.50 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 5, 34)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 5, 64)     │      6,592 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 5, 64)     │        128 │ conv1d[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 5, 128)    │     24,704 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 128)    │        256 │ conv1d_1[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 5, 256)    │     98,560 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 256)    │        512 │ conv1d_2[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 5, 256)    │     65,792 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 5, 256)    │          0 │ layer_normalizat… │
# │                     │                   │            │ conv1d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 5, 256)    │     65,792 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 5, 256)    │          0 │ multiply[0][0],   │
# │                     │                   │            │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 256)    │        512 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 5, 128)    │     98,432 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 128)    │        256 │ conv1d_5[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 5, 64)     │     24,640 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 64)     │        128 │ conv1d_6[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 5, 34)     │      6,562 │ layer_normalizat… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 392,866 (1.50 MB)
#  Trainable params: 392,866 (1.50 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1739384399.983532  956085 service.cc:148] XLA service 0x771ccc002e50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1739384399.983765  956085 service.cc:156]   StreamExecutor device (0): NVIDIA RTX A4500, Compute Capability 8.6
# I0000 00:00:1739384399.983779  956085 service.cc:156]   StreamExecutor device (1): NVIDIA RTX A4500, Compute Capability 8.6
# 2025-02-12 10:20:00.098087: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1739384400.551301  956085 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  24/254 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.2175
# I0000 00:00:1739384403.680497  956085 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - loss: 1.1048 - val_loss: 0.4235
# Epoch 2/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3846 - val_loss: 0.3150
# Epoch 3/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2974 - val_loss: 0.2635
# Epoch 4/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2432 - val_loss: 0.2253
# Epoch 5/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2146 - val_loss: 0.1998
# Epoch 6/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1873 - val_loss: 0.1801
# Epoch 7/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1680 - val_loss: 0.1612
# Epoch 8/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1490 - val_loss: 0.1485
# Epoch 9/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1388 - val_loss: 0.1376
# Epoch 10/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1284 - val_loss: 0.1287
# Epoch 11/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1199 - val_loss: 0.1198
# Epoch 12/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1100 - val_loss: 0.1129
# Epoch 13/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1056 - val_loss: 0.1093
# Epoch 14/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0986 - val_loss: 0.1053
# Epoch 15/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0947 - val_loss: 0.1003
# Epoch 16/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0911 - val_loss: 0.0941
# Epoch 17/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0865 - val_loss: 0.0929
# Epoch 18/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0841 - val_loss: 0.0902
# Epoch 19/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0831 - val_loss: 0.0858
# Epoch 20/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0785 - val_loss: 0.0843
# Epoch 21/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0771 - val_loss: 0.0810
# Epoch 22/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0742 - val_loss: 0.0802
# Epoch 23/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0703 - val_loss: 0.0781
# Epoch 24/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0695 - val_loss: 0.0750
# Epoch 25/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0683 - val_loss: 0.0746
# Epoch 26/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0674 - val_loss: 0.0723
# Epoch 27/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0647 - val_loss: 0.0741
# Epoch 28/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0650 - val_loss: 0.0693
# Epoch 29/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0613 - val_loss: 0.0684
# Epoch 30/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0597 - val_loss: 0.0677
# Epoch 31/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0596 - val_loss: 0.0674
# Epoch 32/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0601 - val_loss: 0.0648
# Epoch 33/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0573 - val_loss: 0.0651
# Epoch 34/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0560 - val_loss: 0.0629
# Epoch 35/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0552 - val_loss: 0.0627
# Epoch 36/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0527 - val_loss: 0.0610
# Epoch 37/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0533 - val_loss: 0.0603
# Epoch 38/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0518 - val_loss: 0.0594
# Epoch 39/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0508 - val_loss: 0.0583
# Epoch 40/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0489 - val_loss: 0.0576
# Epoch 41/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0492 - val_loss: 0.0570
# Epoch 42/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0473 - val_loss: 0.0578
# Epoch 43/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0465 - val_loss: 0.0556
# Epoch 44/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0467 - val_loss: 0.0541
# Epoch 45/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0456 - val_loss: 0.0548
# Epoch 46/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0448 - val_loss: 0.0535
# Epoch 47/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0442 - val_loss: 0.0550
# Epoch 48/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0440 - val_loss: 0.0534
# Epoch 49/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0429 - val_loss: 0.0515
# Epoch 50/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0413 - val_loss: 0.0508
# Epoch 51/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0420 - val_loss: 0.0499
# Epoch 52/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0401 - val_loss: 0.0498
# Epoch 53/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0394 - val_loss: 0.0493
# Epoch 54/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0396 - val_loss: 0.0489
# Epoch 55/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0389 - val_loss: 0.0481
# Epoch 56/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0384 - val_loss: 0.0480
# Epoch 57/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0384 - val_loss: 0.0474
# Epoch 58/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0379 - val_loss: 0.0473
# Epoch 59/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0361 - val_loss: 0.0457
# Epoch 60/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0355 - val_loss: 0.0457
# Epoch 61/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0358 - val_loss: 0.0459
# Epoch 62/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0354 - val_loss: 0.0456
# Epoch 63/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0359 - val_loss: 0.0441
# Epoch 64/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0344 - val_loss: 0.0450
# Epoch 65/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0341 - val_loss: 0.0429
# Epoch 66/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0335 - val_loss: 0.0436
# Epoch 67/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0331 - val_loss: 0.0436
# Epoch 68/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0324 - val_loss: 0.0421
# Epoch 69/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0316 - val_loss: 0.0421
# Epoch 70/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0318 - val_loss: 0.0414
# Epoch 71/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0316 - val_loss: 0.0409
# Epoch 72/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0314 - val_loss: 0.0410
# Epoch 73/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0299 - val_loss: 0.0400
# Epoch 74/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0306 - val_loss: 0.0393
# Epoch 75/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0291 - val_loss: 0.0393
# Epoch 76/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0293 - val_loss: 0.0397
# Epoch 77/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0285 - val_loss: 0.0407
# Epoch 78/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0292 - val_loss: 0.0382
# Epoch 79/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0280 - val_loss: 0.0384
# Epoch 80/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0280 - val_loss: 0.0380
# Epoch 81/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0282 - val_loss: 0.0383
# Epoch 82/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0271 - val_loss: 0.0368
# Epoch 83/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0276 - val_loss: 0.0371
# Epoch 84/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0270 - val_loss: 0.0373
# Epoch 85/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0269 - val_loss: 0.0367
# Epoch 86/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0261 - val_loss: 0.0355
# Epoch 87/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0255 - val_loss: 0.0368
# Epoch 88/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0264 - val_loss: 0.0351
# Epoch 89/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0259 - val_loss: 0.0362
# Epoch 90/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0251 - val_loss: 0.0344
# Epoch 91/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0249 - val_loss: 0.0346
# Epoch 92/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0245 - val_loss: 0.0346
# Epoch 93/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0240 - val_loss: 0.0347
# Epoch 94/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0239 - val_loss: 0.0342
# Epoch 95/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0240 - val_loss: 0.0337
# Epoch 96/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0229 - val_loss: 0.0341
# Epoch 97/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0230 - val_loss: 0.0333
# Epoch 98/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0227 - val_loss: 0.0331
# Epoch 99/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0227 - val_loss: 0.0331
# Epoch 100/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0227 - val_loss: 0.0327
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step
# (9000, 17, 2)

# %% [markdown]
# ## m6

# %%
## m6
prediction_m6t1 = run_model_6(epochs=200, batch_size=32, optimizer=Adam(1e-3))
print(prediction_m6t1.shape)
np.save('../results/r2/prediction_m6t1.npy', prediction_m6t1)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 5, 34)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 5, 128)         │         4,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5, 64)          │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5, 32)          │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5, 64)          │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 5, 128)         │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 5, 34)          │         4,386 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,634 (115.76 KB)
#  Trainable params: 29,634 (115.76 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 5, 34)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 5, 128)         │         4,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5, 64)          │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5, 32)          │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5, 64)          │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 5, 128)         │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 5, 34)          │         4,386 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,634 (115.76 KB)
#  Trainable params: 29,634 (115.76 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 2025-02-12 10:23:49.696220: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-02-12 10:23:50.035239: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-02-12 10:23:50.188334: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4', 200 bytes spill stores, 200 bytes spill loads
#
# 2025-02-12 10:23:50.283404: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4', 168 bytes spill stores, 168 bytes spill loads
#
# 2025-02-12 10:23:52.010638: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5', 16 bytes spill stores, 16 bytes spill loads
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 18s 36ms/step - loss: 1.2909 - val_loss: 0.6019
# Epoch 2/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5527 - val_loss: 0.4290
# Epoch 3/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4239 - val_loss: 0.3529
# Epoch 4/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3491 - val_loss: 0.3044
# Epoch 5/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3080 - val_loss: 0.2688
# Epoch 6/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2676 - val_loss: 0.2433
# Epoch 7/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2362 - val_loss: 0.2244
# Epoch 8/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2221 - val_loss: 0.2100
# Epoch 9/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2085 - val_loss: 0.1983
# Epoch 10/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1954 - val_loss: 0.1877
# Epoch 11/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1876 - val_loss: 0.1750
# Epoch 12/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1786 - val_loss: 0.1643
# Epoch 13/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1624 - val_loss: 0.1556
# Epoch 14/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1582 - val_loss: 0.1478
# Epoch 15/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1464 - val_loss: 0.1411
# Epoch 16/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1376 - val_loss: 0.1349
# Epoch 17/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1318 - val_loss: 0.1309
# Epoch 18/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1281 - val_loss: 0.1255
# Epoch 19/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1250 - val_loss: 0.1221
# Epoch 20/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1188 - val_loss: 0.1181
# Epoch 21/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1164 - val_loss: 0.1150
# Epoch 22/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1151 - val_loss: 0.1120
# Epoch 23/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.1117 - val_loss: 0.1100
# Epoch 24/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1082 - val_loss: 0.1075
# Epoch 25/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1051 - val_loss: 0.1052
# Epoch 26/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1035 - val_loss: 0.1028
# Epoch 27/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1015 - val_loss: 0.1010
# Epoch 28/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0987 - val_loss: 0.0996
# Epoch 29/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0959 - val_loss: 0.0981
# Epoch 30/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0949 - val_loss: 0.0965
# Epoch 31/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0947 - val_loss: 0.0951
# Epoch 32/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0917 - val_loss: 0.0938
# Epoch 33/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0917 - val_loss: 0.0927
# Epoch 34/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0871 - val_loss: 0.0911
# Epoch 35/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0886 - val_loss: 0.0897
# Epoch 36/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0850 - val_loss: 0.0885
# Epoch 37/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0853 - val_loss: 0.0872
# Epoch 38/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0843 - val_loss: 0.0872
# Epoch 39/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0826 - val_loss: 0.0858
# Epoch 40/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0808 - val_loss: 0.0844
# Epoch 41/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0810 - val_loss: 0.0836
# Epoch 42/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0791 - val_loss: 0.0818
# Epoch 43/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0797 - val_loss: 0.0817
# Epoch 44/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0793 - val_loss: 0.0808
# Epoch 45/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0772 - val_loss: 0.0795
# Epoch 46/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0770 - val_loss: 0.0790
# Epoch 47/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0762 - val_loss: 0.0785
# Epoch 48/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0761 - val_loss: 0.0770
# Epoch 49/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0732 - val_loss: 0.0779
# Epoch 50/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0748 - val_loss: 0.0765
# Epoch 51/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0740 - val_loss: 0.0759
# Epoch 52/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0724 - val_loss: 0.0768
# Epoch 53/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0711 - val_loss: 0.0745
# Epoch 54/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0721 - val_loss: 0.0745
# Epoch 55/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0706 - val_loss: 0.0742
# Epoch 56/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0689 - val_loss: 0.0737
# Epoch 57/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0705 - val_loss: 0.0737
# Epoch 58/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0682 - val_loss: 0.0723
# Epoch 59/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0691 - val_loss: 0.0723
# Epoch 60/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0697 - val_loss: 0.0717
# Epoch 61/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0688 - val_loss: 0.0718
# Epoch 62/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0680 - val_loss: 0.0715
# Epoch 63/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0678 - val_loss: 0.0699
# Epoch 64/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0687 - val_loss: 0.0700
# Epoch 65/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0667 - val_loss: 0.0697
# Epoch 66/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0660 - val_loss: 0.0693
# Epoch 67/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0659 - val_loss: 0.0685
# Epoch 68/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0670 - val_loss: 0.0684
# Epoch 69/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0657 - val_loss: 0.0686
# Epoch 70/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0635 - val_loss: 0.0679
# Epoch 71/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0660 - val_loss: 0.0673
# Epoch 72/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0642 - val_loss: 0.0676
# Epoch 73/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0654 - val_loss: 0.0666
# Epoch 74/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0634 - val_loss: 0.0668
# Epoch 75/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0636 - val_loss: 0.0667
# Epoch 76/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0634 - val_loss: 0.0662
# Epoch 77/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0623 - val_loss: 0.0663
# Epoch 78/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0622 - val_loss: 0.0657
# Epoch 79/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0626 - val_loss: 0.0651
# Epoch 80/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0641 - val_loss: 0.0654
# Epoch 81/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0619 - val_loss: 0.0650
# Epoch 82/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0620 - val_loss: 0.0648
# Epoch 83/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0621 - val_loss: 0.0644
# Epoch 84/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0602 - val_loss: 0.0645
# Epoch 85/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0621 - val_loss: 0.0639
# Epoch 86/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0613 - val_loss: 0.0645
# Epoch 87/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0602 - val_loss: 0.0638
# Epoch 88/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0604 - val_loss: 0.0635
# Epoch 89/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0613 - val_loss: 0.0631
# Epoch 90/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0602 - val_loss: 0.0630
# Epoch 91/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0594 - val_loss: 0.0630
# Epoch 92/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0593 - val_loss: 0.0625
# Epoch 93/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0591 - val_loss: 0.0629
# Epoch 94/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0591 - val_loss: 0.0623
# Epoch 95/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0585 - val_loss: 0.0615
# Epoch 96/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0586 - val_loss: 0.0616
# Epoch 97/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0592 - val_loss: 0.0615
# Epoch 98/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0590 - val_loss: 0.0613
# Epoch 99/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0587 - val_loss: 0.0609
# Epoch 100/100
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0562 - val_loss: 0.0609
# 257/282 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2025-02-12 10:26:38.518112: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 12 bytes spill stores, 12 bytes spill loads
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step
# (9000, 17, 2)

# %% [markdown]
# ## m8

# %%
prediction_m8t1 = run_model_8(epochs=100, batch_size=32, optimizer=Adam(1e-4))
print(prediction_m8t1.shape)
np.save('../results/r2/prediction_m8t1.npy', prediction_m8t1)

# %% [markdown]
# ## m9

# %% [markdown]
# t2: 50 epochs, 2 layers
#
# t3: 200 epochs, 2 layers, interpolate corrected data only (?)
#
# t4: 200 epochs, 5 layers, 1e-3 lr
#
# t5: 200 epochs, 5 layers, 1e-4 lr
#
# t6: 200 epochs, 2 layers, 1e-4 lr, interpolate augmented data only
#
# t7: 200 epochs, 2 layers, 5e-4 lr, 64 batch size, 0.01 swap_rate
#
# t8: 200 epochs, 5 layers, 5e-4 lr, 64 batch size, 0.005 swap_rate
#
# t9: 200 epochs, 5 layers, 5e-4 lr, 128 batch size, 0.005 swap_rate, interpolate all inputs but only loss on non-missing points

# %%
prediction_m9t1 = run_model_9(epochs=200, batch_size=64, optimizer=Adam(5e-4), num_layers=5, 
                              dropout_rate=0.01, swap_rate=0.01)
print(prediction_m9t1.shape)
np.save('../results/r2/prediction_m9t9.npy', prediction_m9t1)
# Out:
# I0000 00:00:1739404973.539639 1632136 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18071 MB memory:  -> device: 0, name: NVIDIA RTX A4500, pci bus id: 0000:17:00.0, compute capability: 8.6
# I0000 00:00:1739404973.545429 1632136 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 17706 MB memory:  -> device: 1, name: NVIDIA RTX A4500, pci bus id: 0000:73:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 5, 34)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ learnable_position… │ (None, 5, 34)     │        170 │ input_layer[0][0] │
# │ (LearnablePosition… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 34)     │     35,618 │ learnable_positi… │
# │ (MultiHeadAttentio… │                   │            │ learnable_positi… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 5, 34)     │          0 │ learnable_positi… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 5, 34)     │         68 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 5, 512)    │     17,920 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 5, 34)     │     17,442 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 34)     │     35,618 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 5, 512)    │     17,920 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 5, 34)     │     17,442 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 34)     │     35,618 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 5, 512)    │     17,920 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 5, 34)     │     17,442 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 34)     │     35,618 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 5, 512)    │     17,920 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 5, 34)     │     17,442 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 34)     │     35,618 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 5, 512)    │     17,920 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 5, 34)     │     17,442 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 34)        │          0 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 34)        │      1,190 │ get_item[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 356,940 (1.36 MB)
#  Trainable params: 356,940 (1.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 5, 34)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ learnable_position… │ (None, 5, 34)     │        170 │ input_layer[0][0] │
# │ (LearnablePosition… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 34)     │     35,618 │ learnable_positi… │
# │ (MultiHeadAttentio… │                   │            │ learnable_positi… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 5, 34)     │          0 │ learnable_positi… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 5, 34)     │         68 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 5, 512)    │     17,920 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 5, 34)     │     17,442 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 34)     │     35,618 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 5, 512)    │     17,920 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 5, 34)     │     17,442 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 34)     │     35,618 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 5, 512)    │     17,920 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 5, 34)     │     17,442 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 34)     │     35,618 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 5, 512)    │     17,920 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 5, 34)     │     17,442 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 5, 34)     │     35,618 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 5, 512)    │     17,920 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 5, 34)     │     17,442 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 5, 34)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 5, 34)     │         68 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 34)        │          0 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 34)        │      1,190 │ get_item[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 356,940 (1.36 MB)
#  Trainable params: 356,940 (1.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1739404995.189442 1632554 service.cc:148] XLA service 0x7a5f8400f260 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1739404995.189468 1632554 service.cc:156]   StreamExecutor device (0): NVIDIA RTX A4500, Compute Capability 8.6
# I0000 00:00:1739404995.189472 1632554 service.cc:156]   StreamExecutor device (1): NVIDIA RTX A4500, Compute Capability 8.6
# 2025-02-12 16:03:15.582110: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1739404998.514257 1632554 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-02-12 16:03:21.726927: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_136', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-02-12 16:03:21.963459: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_136', 132 bytes spill stores, 132 bytes spill loads
#
# 2025-02-12 16:03:21.973109: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_136', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-02-12 16:03:21.986883: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_136', 52 bytes spill stores, 52 bytes spill loads
#
# 2025-02-12 16:03:22.073733: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_136', 100 bytes spill stores, 108 bytes spill loads
#
# 2025-02-12 16:03:22.081134: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_136', 364 bytes spill stores, 364 bytes spill loads
#
# 2025-02-12 16:03:22.105408: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_7', 16 bytes spill stores, 16 bytes spill loads
#  16/127 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8105
# I0000 00:00:1739405012.358554 1632554 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 124/127 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9394
# 2025-02-12 16:03:40.774017: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_136', 104 bytes spill stores, 116 bytes spill loads
#
# 2025-02-12 16:03:40.912078: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_136', 132 bytes spill stores, 132 bytes spill loads
#
# 2025-02-12 16:03:40.918222: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_136', 52 bytes spill stores, 52 bytes spill loads
#
# 2025-02-12 16:03:41.003548: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_7', 24 bytes spill stores, 24 bytes spill loads
#
# 2025-02-12 16:03:41.049253: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_136', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-02-12 16:03:41.062999: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_136', 364 bytes spill stores, 364 bytes spill loads
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 0.9316
# 2025-02-12 16:04:01.088405: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_7', 24 bytes spill stores, 24 bytes spill loads
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 65s 239ms/step - loss: 0.9291 - val_loss: 0.3973
# Epoch 2/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.3508 - val_loss: 0.2831
# Epoch 3/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.2603 - val_loss: 0.2252
# Epoch 4/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.2103 - val_loss: 0.1904
# Epoch 5/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1700 - val_loss: 0.1655
# Epoch 6/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1430 - val_loss: 0.1397
# Epoch 7/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1186 - val_loss: 0.1192
# Epoch 8/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.1046 - val_loss: 0.1112
# Epoch 9/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0915 - val_loss: 0.0934
# Epoch 10/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0776 - val_loss: 0.0853
# Epoch 11/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0713 - val_loss: 0.0844
# Epoch 12/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0612 - val_loss: 0.0746
# Epoch 13/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0607 - val_loss: 0.0658
# Epoch 14/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0514 - val_loss: 0.0627
# Epoch 15/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0487 - val_loss: 0.0586
# Epoch 16/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0419 - val_loss: 0.0543
# Epoch 17/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0404 - val_loss: 0.0508
# Epoch 18/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0368 - val_loss: 0.0487
# Epoch 19/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0327 - val_loss: 0.0541
# Epoch 20/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0338 - val_loss: 0.0438
# Epoch 21/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0289 - val_loss: 0.0405
# Epoch 22/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.0269 - val_loss: 0.0407
# Epoch 23/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0260 - val_loss: 0.0356
# Epoch 24/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0231 - val_loss: 0.0354
# Epoch 25/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0241 - val_loss: 0.0337
# Epoch 26/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0217 - val_loss: 0.0305
# Epoch 27/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0216 - val_loss: 0.0343
# Epoch 28/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0209 - val_loss: 0.0328
# Epoch 29/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0197 - val_loss: 0.0324
# Epoch 30/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0187 - val_loss: 0.0271
# Epoch 31/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0168 - val_loss: 0.0282
# Epoch 32/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0156 - val_loss: 0.0284
# Epoch 33/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0152 - val_loss: 0.0269
# Epoch 34/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0143 - val_loss: 0.0271
# Epoch 35/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0157 - val_loss: 0.0286
# Epoch 36/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0140 - val_loss: 0.0259
# Epoch 37/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0125 - val_loss: 0.0242
# Epoch 38/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0119 - val_loss: 0.0327
# Epoch 39/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0184 - val_loss: 0.0372
# Epoch 40/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0247 - val_loss: 0.0421
# Epoch 41/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0194 - val_loss: 0.0270
# Epoch 42/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0159 - val_loss: 0.0214
# Epoch 43/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0105 - val_loss: 0.0199
# Epoch 44/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0104 - val_loss: 0.0214
# Epoch 45/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0112 - val_loss: 0.0202
# Epoch 46/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0082 - val_loss: 0.0202
# Epoch 47/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0088 - val_loss: 0.0189
# Epoch 48/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0069 - val_loss: 0.0244
# Epoch 49/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0117 - val_loss: 0.0214
# Epoch 50/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0111 - val_loss: 0.0482
# Epoch 51/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0463 - val_loss: 0.0485
# Epoch 52/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0246 - val_loss: 0.0232
# Epoch 53/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0104 - val_loss: 0.0174
# Epoch 54/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0087 - val_loss: 0.0198
# Epoch 55/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0069 - val_loss: 0.0164
# Epoch 56/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0060 - val_loss: 0.0153
# Epoch 57/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0058 - val_loss: 0.0168
# Epoch 58/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0051 - val_loss: 0.0207
# Epoch 59/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0118 - val_loss: 0.0223
# Epoch 60/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0106 - val_loss: 0.0156
# Epoch 61/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0053 - val_loss: 0.0163
# Epoch 62/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0055 - val_loss: 0.0161
# Epoch 63/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0052 - val_loss: 0.0153
# Epoch 64/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0047 - val_loss: 0.0147
# Epoch 65/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0046 - val_loss: 0.0145
# Epoch 66/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0046 - val_loss: 0.0189
# Epoch 67/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0196 - val_loss: 0.1338
# Epoch 68/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0732 - val_loss: 0.0278
# Epoch 69/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0136 - val_loss: 0.0173
# Epoch 70/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0067 - val_loss: 0.0160
# Epoch 71/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0054 - val_loss: 0.0157
# Epoch 72/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0048 - val_loss: 0.0139
# Epoch 73/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0040 - val_loss: 0.0146
# Epoch 74/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0041 - val_loss: 0.0141
# Epoch 75/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0037 - val_loss: 0.0144
# Epoch 76/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0035 - val_loss: 0.0141
# Epoch 77/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0036 - val_loss: 0.0138
# Epoch 78/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0036 - val_loss: 0.0139
# Epoch 79/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0033 - val_loss: 0.0138
# Epoch 80/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0042 - val_loss: 0.0146
# Epoch 81/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0038 - val_loss: 0.0147
# Epoch 82/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0040 - val_loss: 0.0146
# Epoch 83/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0037 - val_loss: 0.0141
# Epoch 84/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0036 - val_loss: 0.0139
# Epoch 85/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0033 - val_loss: 0.0138
# Epoch 86/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0040 - val_loss: 0.0197
# Epoch 87/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0444 - val_loss: 0.0576
# Epoch 88/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0306 - val_loss: 0.0211
# Epoch 89/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0083 - val_loss: 0.0161
# Epoch 90/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0053 - val_loss: 0.0152
# Epoch 91/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0050 - val_loss: 0.0140
# Epoch 92/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0041 - val_loss: 0.0139
# Epoch 93/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0035 - val_loss: 0.0146
# Epoch 94/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0039 - val_loss: 0.0253
# Epoch 95/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0165 - val_loss: 0.0183
# Epoch 96/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0053 - val_loss: 0.0134
# Epoch 97/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0037 - val_loss: 0.0132
# Epoch 98/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0029 - val_loss: 0.0142
# Epoch 99/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0031 - val_loss: 0.0132
# Epoch 100/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0028 - val_loss: 0.0132
# Epoch 101/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0028 - val_loss: 0.0133
# Epoch 102/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0026 - val_loss: 0.0130
# Epoch 103/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0025 - val_loss: 0.0134
# Epoch 104/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0030 - val_loss: 0.0143
# Epoch 105/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0201 - val_loss: 0.0905
# Epoch 106/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0489 - val_loss: 0.0247
# Epoch 107/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0109 - val_loss: 0.0148
# Epoch 108/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0045 - val_loss: 0.0149
# Epoch 109/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0038 - val_loss: 0.0138
# Epoch 110/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0032 - val_loss: 0.0139
# Epoch 111/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0028 - val_loss: 0.0135
# Epoch 112/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0029 - val_loss: 0.0136
# Epoch 113/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0028 - val_loss: 0.0133
# Epoch 114/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0027 - val_loss: 0.0134
# Epoch 115/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0026 - val_loss: 0.0133
# Epoch 116/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0025 - val_loss: 0.0135
# Epoch 117/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0024 - val_loss: 0.0137
# Epoch 118/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0024 - val_loss: 0.0136
# Epoch 119/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0023 - val_loss: 0.0138
# Epoch 120/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0025 - val_loss: 0.0136
# Epoch 121/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0023 - val_loss: 0.0139
# Epoch 122/200
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0024 - val_loss: 0.0138
# Epoch 122: early stopping
# Restoring model weights from the end of the best epoch: 102.
# 2025-02-12 16:08:21.226446: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_7', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-02-12 16:08:21.298426: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_41', 104 bytes spill stores, 116 bytes spill loads
#
# 2025-02-12 16:08:21.374566: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_41', 52 bytes spill stores, 52 bytes spill loads
#
# 2025-02-12 16:08:21.411985: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_41', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-02-12 16:08:21.514490: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_41', 132 bytes spill stores, 132 bytes spill loads
#
# 2025-02-12 16:08:21.648928: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_41', 364 bytes spill stores, 364 bytes spill loads
# 274/282 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 2025-02-12 16:08:28.856399: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_7', 24 bytes spill stores, 24 bytes spill loads
#
# 2025-02-12 16:08:29.111835: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_41', 104 bytes spill stores, 116 bytes spill loads
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step
# (9000, 17, 2)
