# %%
from run_models import *
# Out:
# 2025-02-12 01:31:13.635291: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-12 01:31:13.843429: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739352673.974589  777613 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739352674.015557  777613 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## m1

# %%
prediction_m1t1 = run_model_1(epochs=200, batch_size=32, optimizer=Adam(1e-4))
print(prediction_m1t1.shape)
np.save('../results/r2/prediction_m1t1.npy', prediction_m1t1)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 5, 34)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 5, 64)          │        25,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector_1 (RepeatVector)  │ (None, 5, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 5, 32)          │         8,320 │
# ...

# %% [markdown]
# ## m2

# %%
prediction_m2t1 = run_model_2(epochs=200, batch_size=32, optimizer=Adam(1e-4))
print(prediction_m2t1.shape)
np.save('../results/r2/prediction_m2t1.npy', prediction_m2t1)
# Out:
# Model: "temporal_autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_sequence (InputLayer)     │ (None, 5, 17, 2)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalize (Lambda)              │ (None, 5, 17, 2)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_per_frame               │ (None, 5, 34)          │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise (GaussianNoise)  │ (None, 5, 34)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# ## m3

# %%
prediction_m3t1 = run_model_3(epochs=100, batch_size=32, optimizer=Adam(1e-4))
print(prediction_m3t1.shape)
np.save('../results/r2/prediction_m3t1.npy', prediction_m3t1)
# Out:
# I0000 00:00:1739352683.552695  777613 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18247 MB memory:  -> device: 0, name: NVIDIA RTX A4500, pci bus id: 0000:17:00.0, compute capability: 8.6
# I0000 00:00:1739352683.555462  777613 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 17691 MB memory:  -> device: 1, name: NVIDIA RTX A4500, pci bus id: 0000:73:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 5, 170,    │          0 │ -                 │
# │ (InputLayer)        │ 174, 1)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# ## m4

# %%
prediction_m4t1 = run_model_4(epochs=100, batch_size=32, optimizer=Adam(1e-4))
print(prediction_m4t1.shape)
np.save('../results/r2/prediction_m4t1.npy', prediction_m4t1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 prediction_m4t1 = run_model_4(epochs=100, batch_size=32, optimizer=Adam(1e-4))
#       2 print(prediction_m4t1.shape)
#       3 np.save('../results/r2/prediction_m4t1.npy', prediction_m4t1)
#
# File ~/Desktop/jelly-sleap/sleap/jelly/autoencoder/2min/run_models.py:143, in run_model_4(train_slice_only, window_size, epochs, batch_size, optimizer)
#     142 def run_model_4(train_slice_only=True, window_size=5, epochs=100, batch_size=32, optimizer='adam'):
# --> 143     X_train, X_val, y_train, y_val, X = load_data(window_size=window_size, augment=True, load_video=True)
#     145     model = get_model_4(window_size=window_size)
#     146     model.compile(optimizer=optimizer, loss=masked_mse_loss)
#
# ...

# %% [markdown]
# ## m5

# %%
prediction_m5t1 = run_model_5(epochs=100, batch_size=32, optimizer=Adam(1e-4))
print(prediction_m5t1.shape)
np.save('../results/r2/prediction_m5t1.npy', prediction_m5t1)

# %% [markdown]
# ## m6

# %%
## m6
prediction_m6t1 = run_model_6(epochs=100, batch_size=32, optimizer=Adam(1e-4))
print(prediction_m6t1.shape)
np.save('../results/r2/prediction_m6t1.npy', prediction_m6t1)

# %% [markdown]
# ## m8

# %%
prediction_m8t1 = run_model_8(epochs=100, batch_size=32, optimizer=Adam(1e-4))
print(prediction_m8t1.shape)
np.save('../results/r2/prediction_m8t1.npy', prediction_m8t1)

# %% [markdown]
# ## m9

# %%
prediction_m9t1 = run_model_9(epochs=100, batch_size=32, optimizer=Adam(1e-4))
print(prediction_m9t1.shape)
np.save('../results/r2/prediction_m9t1.npy', prediction_m9t1)
