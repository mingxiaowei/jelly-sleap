# %%
import sleap
import numpy as np
import matplotlib.pyplot as plt
import os, sys
import datetime

sys.path.append('..')
sys.path.append('../..')
sys.path.append('/Users/mingxiaowei/Desktop/kennedylab/turbulence/jelly-sleap/sleap/jelly/autoencoder/')
from src.data_loader import *
from min2.run_models import *
from python.postprocess import *
from python.animation import *

# %%
# thresholds = [15, 20, 30, 40, 45, 50]
thresholds = [4, 6, 8, 10, 12]
all_pp3_pts_3k = []
pp_dir = '/Users/mingxiaowei/Desktop/kennedylab/turbulence/jellyfish/video/video_1_clips/postprocess'
for thres in thresholds:
    pp_path = os.path.join(pp_dir, f'a1_raw_pts_pp3_thres{thres}.npy')
    if os.path.exists(pp_path):
    # if False:
        pp_pts = np.load(pp_path)
        all_pp3_pts_3k.append(pp_pts)
    else:
        pp_pts = preprocess3(pred_pts, thres=thres)
        all_pp3_pts_3k.append(pp_pts)
        np.save(pp_path, pp_pts)
all_pp3_pts_3k = np.array(all_pp3_pts_3k)
print(all_pp3_pts_3k.shape)
# Out:
# (5, 3000, 17, 2)

# %%
pp_pts_t6 = all_pp3_pts_3k[1]
pp_pts_t12 = all_pp3_pts_3k[4]

# %%
def t6_loader(*args, **kwargs):
    return load_data(coords_corrected=pp_pts_t6, *args, **kwargs)
def t12_loader(*args, **kwargs):
    return load_data(coords_corrected=pp_pts_t12, *args, **kwargs)

# %% [markdown]
# # m11

# %% [markdown]
# ## thres6

# %% [markdown]
# ### t1

# %%
m11 = get_model_11(window_size=50, pt_cnt=17, latent_dim=32, num_layers=5)
# tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
prediction_m11t1 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4), 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, 
                              model=m11, data_loader=t6_loader)
print(prediction_m11t1.shape)
np.save('../results/r11/prediction_m11t1.npy', prediction_m11t1)
# Out:
# Metal device set to: Apple M2
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2025-04-06 15:26:11.784971: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-06 15:26:11.786591: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 50, 34)]          0
#
#  dense (Dense)               (None, 50, 1024)          35840
#
#  dense_1 (Dense)             (None, 50, 512)           524800
#
# ...
