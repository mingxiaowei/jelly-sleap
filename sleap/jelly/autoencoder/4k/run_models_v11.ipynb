# %%
import sleap
import numpy as np
import matplotlib.pyplot as plt
import os, sys
import datetime

sys.path.append('..')
sys.path.append('../..')
sys.path.append('/Users/mingxiaowei/Desktop/kennedylab/turbulence/jelly-sleap/sleap/jelly/autoencoder/')
from src.data_loader import *
from min2.run_models import *
from python.postprocess import *
from python.animation import *

# %%
# thresholds = [15, 20, 30, 40, 45, 50]
thresholds = [4, 6, 8, 10, 12]
all_pp3_pts_3k = []
pp_dir = '/Users/mingxiaowei/Desktop/kennedylab/turbulence/jellyfish/video/video_1_clips/postprocess'
for thres in thresholds:
    pp_path = os.path.join(pp_dir, f'a1_raw_pts_pp3_thres{thres}.npy')
    if os.path.exists(pp_path):
    # if False:
        pp_pts = np.load(pp_path)
        all_pp3_pts_3k.append(pp_pts)
    else:
        pp_pts = preprocess3(pred_pts, thres=thres)
        all_pp3_pts_3k.append(pp_pts)
        np.save(pp_path, pp_pts)
all_pp3_pts_3k = np.array(all_pp3_pts_3k)
print(all_pp3_pts_3k.shape)
# Out:
# (5, 3000, 17, 2)

# %%
pp_pts_t6 = all_pp3_pts_3k[1]
pp_pts_t12 = all_pp3_pts_3k[4]

def t6_loader(*args, **kwargs):
    return load_data(coords_corrected=pp_pts_t6, *args, **kwargs)
def t12_loader(*args, **kwargs):
    return load_data(coords_corrected=pp_pts_t12, *args, **kwargs)

# %% [markdown]
# # m11

# %% [markdown]
# ## thres6

# %% [markdown]
# ### t1

# %%
m11 = get_model_11(window_size=50, pt_cnt=17, latent_dim=32, num_layers=5)
# tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
prediction_m11t1 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4), 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, 
                              model=m11, data_loader=t6_loader)
print(prediction_m11t1.shape)
np.save('../results/r11/prediction_m11t1.npy', prediction_m11t1)
# Out:
# Metal device set to: Apple M2
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2025-04-06 15:26:11.784971: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-06 15:26:11.786591: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 50, 34)]          0
#
#  dense (Dense)               (None, 50, 1024)          35840
#
#  dense_1 (Dense)             (None, 50, 512)           524800
#
# ...

# %% [markdown]
# ### t2

# %%
m11 = get_model_11(window_size=50, pt_cnt=17, latent_dim=64, num_layers=4)
# tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
prediction_m11t2 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4), 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, 
                              model=m11, data_loader=t6_loader)
print(prediction_m11t2.shape)
np.save('../results/r11/prediction_m11t2.npy', prediction_m11t2)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 50, 34)]          0
#
#  dense_12 (Dense)            (None, 50, 1024)          35840
#
#  dense_13 (Dense)            (None, 50, 512)           524800
#
#  dense_14 (Dense)            (None, 50, 256)           131328
#
#  dense_15 (Dense)            (None, 50, 128)           32896
#
#  dense_16 (Dense)            (None, 50, 64)            8256
#
#  dense_17 (Dense)            (None, 50, 64)            4160
#
#  dense_18 (Dense)            (None, 50, 128)           8320
#
#  dense_19 (Dense)            (None, 50, 256)           33024
#
#  dense_20 (Dense)            (None, 50, 512)           131584
#
#  tf.__operators__.getitem_1   (None, 512)              0
#  (SlicingOpLambda)
#
#  dense_21 (Dense)            (None, 34)                17442
#
# ...
# Total params: 927,650
# Trainable params: 927,650
# ...

# %% [markdown]
# ### t3

# %%
m11 = get_model_11(window_size=50, pt_cnt=17, latent_dim=32, num_layers=4)
# tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
prediction_m11t3 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4), 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, 
                              model=m11, data_loader=t6_loader)
print(prediction_m11t3.shape)
np.save('../results/r11/prediction_m11t3.npy', prediction_m11t3)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 50, 34)]          0
#
#  dense_22 (Dense)            (None, 50, 512)           17920
#
#  dense_23 (Dense)            (None, 50, 256)           131328
#
#  dense_24 (Dense)            (None, 50, 128)           32896
#
#  dense_25 (Dense)            (None, 50, 64)            8256
#
#  dense_26 (Dense)            (None, 50, 32)            2080
#
#  dense_27 (Dense)            (None, 50, 32)            1056
#
#  dense_28 (Dense)            (None, 50, 64)            2112
#
#  dense_29 (Dense)            (None, 50, 128)           8320
#
#  dense_30 (Dense)            (None, 50, 256)           33024
#
#  tf.__operators__.getitem_2   (None, 256)              0
#  (SlicingOpLambda)
#
#  dense_31 (Dense)            (None, 34)                8738
#
# ...
# Total params: 245,730
# Trainable params: 245,730
# ...

# %% [markdown]
# ## thres12

# %% [markdown]
# ### t4

# %%
m11 = get_model_11(window_size=50, pt_cnt=17, latent_dim=32, num_layers=5)
# tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
prediction_m11t4 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4), 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, 
                              model=m11, data_loader=t12_loader)
print(prediction_m11t4.shape)
np.save('../results/r11/prediction_m11t4.npy', prediction_m11t4)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_4 (InputLayer)        [(None, 50, 34)]          0
#
#  dense_32 (Dense)            (None, 50, 1024)          35840
#
#  dense_33 (Dense)            (None, 50, 512)           524800
#
#  dense_34 (Dense)            (None, 50, 256)           131328
#
#  dense_35 (Dense)            (None, 50, 128)           32896
#
#  dense_36 (Dense)            (None, 50, 64)            8256
#
#  dense_37 (Dense)            (None, 50, 32)            2080
#
#  dense_38 (Dense)            (None, 50, 32)            1056
#
#  dense_39 (Dense)            (None, 50, 64)            2112
#
#  dense_40 (Dense)            (None, 50, 128)           8320
#
#  dense_41 (Dense)            (None, 50, 256)           33024
#
#  dense_42 (Dense)            (None, 50, 512)           131584
#
#  tf.__operators__.getitem_3   (None, 512)              0
# ...

# %% [markdown]
# ### t5

# %%
m11 = get_model_11(window_size=50, pt_cnt=17, latent_dim=64, num_layers=4)
# tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
prediction_m11t5 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4), 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, 
                              model=m11, data_loader=t12_loader)
print(prediction_m11t5.shape)
np.save('../results/r11/prediction_m11t5.npy', prediction_m11t5)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_5 (InputLayer)        [(None, 50, 34)]          0
#
#  dense_44 (Dense)            (None, 50, 1024)          35840
#
#  dense_45 (Dense)            (None, 50, 512)           524800
#
#  dense_46 (Dense)            (None, 50, 256)           131328
#
#  dense_47 (Dense)            (None, 50, 128)           32896
#
#  dense_48 (Dense)            (None, 50, 64)            8256
#
#  dense_49 (Dense)            (None, 50, 64)            4160
#
#  dense_50 (Dense)            (None, 50, 128)           8320
#
#  dense_51 (Dense)            (None, 50, 256)           33024
#
#  dense_52 (Dense)            (None, 50, 512)           131584
#
#  tf.__operators__.getitem_4   (None, 512)              0
#  (SlicingOpLambda)
#
#  dense_53 (Dense)            (None, 34)                17442
#
# ...
# Total params: 927,650
# Trainable params: 927,650
# ...

# %% [markdown]
# # m10

# %% [markdown]
# ## thres6

# %% [markdown]
# ### t1

# %%
m10 = get_model_10(window_size=50, pt_cnt=17, num_layers=4, num_heads=16, key_dim=64, value_dim=64)
prediction_m10t1 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(1e-4), num_layers=5, 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, model=m10, data_loader=t6_loader)
print(prediction_m10t1.shape)
np.save('../results/r11/prediction_m10t1.npy', prediction_m10t1)
# Out:
# Metal device set to: Apple M2
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2025-04-06 18:46:42.467562: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-06 18:46:42.467887: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 50, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 50, 34)      1700        ['input_1[0][0]']
#   (LearnablePositionalEncoding2
#  )
#
# ...

# %% [markdown]
# ### t2

# %%
m10 = get_model_10(window_size=50, pt_cnt=17, num_layers=4, num_heads=16, key_dim=16, value_dim=16)
prediction_m10t2 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(1e-4), num_layers=5, 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, model=m10, data_loader=t6_loader)
print(prediction_m10t2.shape)
np.save('../results/r11/prediction_m10t2.npy', prediction_m10t2)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 50, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 50, 34)      1700        ['input_2[0][0]']
#  _1 (LearnablePositionalEncodin
#  g2)
#
#  multi_head_attention_4 (MultiH  (None, 50, 34)      35618       ['learnable_positional_encoding2_
#  eadAttention)                                                   1[0][0]',
#                                                                   'learnable_positional_encoding2_
#                                                                  1[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 50, 34)      0           ['learnable_positional_encoding2_
#  mbda)                                                           1[0][0]',
# ...

# %% [markdown]
# ## thres12

# %% [markdown]
# ### t3

# %%
m10 = get_model_10(window_size=50, pt_cnt=17, num_layers=4, num_heads=16, key_dim=64, value_dim=64)
prediction_m10t3 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(1e-4), num_layers=5, 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, model=m10, data_loader=t12_loader)
print(prediction_m10t3.shape)
np.save('../results/r11/prediction_m10t3.npy', prediction_m10t3)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 50, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 50, 34)      1700        ['input_3[0][0]']
#  _2 (LearnablePositionalEncodin
#  g2)
#
#  multi_head_attention_8 (MultiH  (None, 50, 34)      142370      ['learnable_positional_encoding2_
#  eadAttention)                                                   2[0][0]',
#                                                                   'learnable_positional_encoding2_
#                                                                  2[0][0]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 50, 34)      0           ['learnable_positional_encoding2_
#  ambda)                                                          2[0][0]',
# ...

# %% [markdown]
# ### t4

# %%
### t4
m10 = get_model_10(window_size=50, pt_cnt=17, num_layers=4, num_heads=16, key_dim=16, value_dim=16)
prediction_m10t4 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(1e-4), num_layers=5, 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, model=m10, data_loader=t12_loader)
print(prediction_m10t4.shape)
np.save('../results/r11/prediction_m10t4.npy', prediction_m10t4)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 50, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 50, 34)      1700        ['input_4[0][0]']
#  _3 (LearnablePositionalEncodin
#  g2)
#
#  multi_head_attention_12 (Multi  (None, 50, 34)      35618       ['learnable_positional_encoding2_
#  HeadAttention)                                                  3[0][0]',
#                                                                   'learnable_positional_encoding2_
#                                                                  3[0][0]']
#
#  tf.__operators__.add_24 (TFOpL  (None, 50, 34)      0           ['learnable_positional_encoding2_
#  ambda)                                                          3[0][0]',
# ...
