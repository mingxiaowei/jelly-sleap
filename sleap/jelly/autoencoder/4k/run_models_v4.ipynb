# %%
import sleap
import numpy as np
import matplotlib.pyplot as plt
import os, sys
import datetime

sys.path.append('..')
sys.path.append('../..')
from src.data_loader import *
from min2.run_models import *
from python.postprocess import *
from python.animation import *

# %% [markdown]
# ## m10

# %% [markdown]
# ### t1

# %%
# %load_ext tensorboard

# %%
prediction_m10t1 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(1e-4), num_layers=5, 
                              window_size=30, dropout_rate=0, swap_rate=0, roll=True)
print(prediction_m10t1.shape)
np.save('../results/r4/prediction_m10t1.npy', prediction_m10t1)
# Out:
# coords_corrected_windows.shape: (9000, 30, 17, 2)
# coords_augmented_windows.shape: (153000, 30, 17, 2)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 30, 34)      1020        ['input_1[0][0]']
#   (LearnablePositionalEncoding2
#  )
#
#  multi_head_attention (MultiHea  (None, 30, 34)      35618       ['learnable_positional_encoding2[
#  dAttention)                                                     0][0]',
#                                                                   'learnable_positional_encoding2[
#                                                                  0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 30, 34)      0           ['learnable_positional_encoding2[
#  da)                                                             0][0]',
#                                                                   'multi_head_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 30, 34)      68          ['tf.__operators__.add[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 30, 512)      17920       ['layer_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 30, 34)       17442       ['dense[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 30, 34)      0           ['layer_normalization[0][0]',
#  mbda)                                                            'dense_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 30, 34)      35618       ['layer_normalization_1[0][0]',
#  eadAttention)                                                    'layer_normalization_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_1[0][0]',
#  mbda)                                                            'multi_head_attention_1[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 30, 512)      17920       ['layer_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 30, 34)       17442       ['dense_2[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_2[0][0]',
#  mbda)                                                            'dense_3[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 30, 34)      35618       ['layer_normalization_3[0][0]',
#  eadAttention)                                                    'layer_normalization_3[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_3[0][0]',
#  mbda)                                                            'multi_head_attention_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_4[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 30, 512)      17920       ['layer_normalization_4[0][0]']
#
#  dense_5 (Dense)                (None, 30, 34)       17442       ['dense_4[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_4[0][0]',
#  mbda)                                                            'dense_5[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 30, 34)      35618       ['layer_normalization_5[0][0]',
#  eadAttention)                                                    'layer_normalization_5[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_5[0][0]',
#  mbda)                                                            'multi_head_attention_3[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_6[0][0]']
#  rmalization)
#
#  dense_6 (Dense)                (None, 30, 512)      17920       ['layer_normalization_6[0][0]']
#
#  dense_7 (Dense)                (None, 30, 34)       17442       ['dense_6[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_6[0][0]',
#  mbda)                                                            'dense_7[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_7[0][0]']
#  rmalization)
#
#  multi_head_attention_4 (MultiH  (None, 30, 34)      35618       ['layer_normalization_7[0][0]',
#  eadAttention)                                                    'layer_normalization_7[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_7[0][0]',
#  mbda)                                                            'multi_head_attention_4[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_8[0][0]']
#  rmalization)
#
#  dense_8 (Dense)                (None, 30, 512)      17920       ['layer_normalization_8[0][0]']
#
#  dense_9 (Dense)                (None, 30, 34)       17442       ['dense_8[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_8[0][0]',
#  mbda)                                                            'dense_9[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_9[0][0]']
#  rmalization)
#
#  tf.__operators__.getitem (Slic  (None, 34)          0           ['layer_normalization_9[0][0]']
#  ingOpLambda)
#
#  dense_10 (Dense)               (None, 34)           1190        ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  reshape (Reshape)              (None, 17, 2)        0           ['dense_10[0][0]']
#
#  lambda (Lambda)                (None, 17, 2)        0           ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 357,790
# Trainable params: 357,790
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 30, 34)      1020        ['input_1[0][0]']
#   (LearnablePositionalEncoding2
#  )
#
#  multi_head_attention (MultiHea  (None, 30, 34)      35618       ['learnable_positional_encoding2[
#  dAttention)                                                     0][0]',
#                                                                   'learnable_positional_encoding2[
#                                                                  0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 30, 34)      0           ['learnable_positional_encoding2[
#  da)                                                             0][0]',
#                                                                   'multi_head_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 30, 34)      68          ['tf.__operators__.add[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 30, 512)      17920       ['layer_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 30, 34)       17442       ['dense[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 30, 34)      0           ['layer_normalization[0][0]',
#  mbda)                                                            'dense_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 30, 34)      35618       ['layer_normalization_1[0][0]',
#  eadAttention)                                                    'layer_normalization_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_1[0][0]',
#  mbda)                                                            'multi_head_attention_1[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 30, 512)      17920       ['layer_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 30, 34)       17442       ['dense_2[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_2[0][0]',
#  mbda)                                                            'dense_3[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 30, 34)      35618       ['layer_normalization_3[0][0]',
#  eadAttention)                                                    'layer_normalization_3[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_3[0][0]',
#  mbda)                                                            'multi_head_attention_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_4[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 30, 512)      17920       ['layer_normalization_4[0][0]']
#
#  dense_5 (Dense)                (None, 30, 34)       17442       ['dense_4[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_4[0][0]',
#  mbda)                                                            'dense_5[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 30, 34)      35618       ['layer_normalization_5[0][0]',
#  eadAttention)                                                    'layer_normalization_5[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_5[0][0]',
#  mbda)                                                            'multi_head_attention_3[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_6[0][0]']
#  rmalization)
#
#  dense_6 (Dense)                (None, 30, 512)      17920       ['layer_normalization_6[0][0]']
#
#  dense_7 (Dense)                (None, 30, 34)       17442       ['dense_6[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_6[0][0]',
#  mbda)                                                            'dense_7[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_7[0][0]']
#  rmalization)
#
#  multi_head_attention_4 (MultiH  (None, 30, 34)      35618       ['layer_normalization_7[0][0]',
#  eadAttention)                                                    'layer_normalization_7[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_7[0][0]',
#  mbda)                                                            'multi_head_attention_4[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_8[0][0]']
#  rmalization)
#
#  dense_8 (Dense)                (None, 30, 512)      17920       ['layer_normalization_8[0][0]']
#
#  dense_9 (Dense)                (None, 30, 34)       17442       ['dense_8[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_8[0][0]',
#  mbda)                                                            'dense_9[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_9[0][0]']
#  rmalization)
#
#  tf.__operators__.getitem (Slic  (None, 34)          0           ['layer_normalization_9[0][0]']
#  ingOpLambda)
#
#  dense_10 (Dense)               (None, 34)           1190        ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  reshape (Reshape)              (None, 17, 2)        0           ['dense_10[0][0]']
#
#  lambda (Lambda)                (None, 17, 2)        0           ['reshape[0][0]']
#
# ==================================================================================================
# Total params: 357,790
# Trainable params: 357,790
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Layer LearnablePositionalEncoding2 has arguments ['self', 'window_size', 'pt_cnt']
# in `__init__` and therefore must override `get_config()`.
#
# Example:
#
# class CustomLayer(keras.layers.Layer):
#     def __init__(self, arg1, arg2):
#         super().__init__()
#         self.arg1 = arg1
#         self.arg2 = arg2
#
#     def get_config(self):
#         config = super().get_config()
#         config.update({
#             "arg1": self.arg1,
#             "arg2": self.arg2,
#         })
#         return config
# Epoch 1/200
# 127/127 [==============================] - 9s 40ms/step - loss: 868.8211 - val_loss: 882.1536
# Epoch 2/200
# 127/127 [==============================] - 4s 35ms/step - loss: 563.1273 - val_loss: 926.3951
# Epoch 3/200
# 127/127 [==============================] - 4s 34ms/step - loss: 560.4199 - val_loss: 864.7293
# Epoch 4/200
# 127/127 [==============================] - 4s 34ms/step - loss: 559.6919 - val_loss: 911.1843
# Epoch 5/200
# 127/127 [==============================] - 4s 34ms/step - loss: 559.9030 - val_loss: 944.7352
# Epoch 6/200
# 127/127 [==============================] - 4s 34ms/step - loss: 559.3759 - val_loss: 861.1476
# Epoch 7/200
# 127/127 [==============================] - 4s 35ms/step - loss: 559.7637 - val_loss: 878.1574
# Epoch 8/200
# 127/127 [==============================] - 5s 36ms/step - loss: 560.0308 - val_loss: 934.9791
# Epoch 9/200
# 127/127 [==============================] - 4s 35ms/step - loss: 559.4123 - val_loss: 899.0554
# Epoch 10/200
# 127/127 [==============================] - 4s 35ms/step - loss: 559.4420 - val_loss: 881.1362
# Epoch 11/200
# 127/127 [==============================] - 4s 35ms/step - loss: 559.0710 - val_loss: 837.0723
# Epoch 12/200
# 127/127 [==============================] - 4s 35ms/step - loss: 559.8138 - val_loss: 838.2281
# Epoch 13/200
# 127/127 [==============================] - 5s 36ms/step - loss: 559.4036 - val_loss: 902.8610
# Epoch 14/200
# 127/127 [==============================] - 4s 35ms/step - loss: 559.0067 - val_loss: 865.3880
# Epoch 15/200
# 127/127 [==============================] - 5s 36ms/step - loss: 558.7732 - val_loss: 925.9775
# Epoch 16/200
# 127/127 [==============================] - 5s 36ms/step - loss: 558.8375 - val_loss: 878.4506
# Epoch 17/200
# 127/127 [==============================] - 4s 35ms/step - loss: 559.6000 - val_loss: 892.7158
# Epoch 18/200
# 127/127 [==============================] - 5s 36ms/step - loss: 559.0616 - val_loss: 883.8257
# Epoch 19/200
# 127/127 [==============================] - 4s 35ms/step - loss: 558.8278 - val_loss: 909.4276
# Epoch 20/200
# 127/127 [==============================] - 4s 35ms/step - loss: 558.8250 - val_loss: 888.7262
# Epoch 21/200
# 127/127 [==============================] - 4s 35ms/step - loss: 558.7378 - val_loss: 868.6061
# Epoch 22/200
# 127/127 [==============================] - 4s 34ms/step - loss: 558.8435 - val_loss: 884.5765
# Epoch 23/200
# 127/127 [==============================] - 5s 36ms/step - loss: 558.9642 - val_loss: 870.3582
# Epoch 24/200
# 127/127 [==============================] - 4s 35ms/step - loss: 558.6642 - val_loss: 891.6951
# Epoch 25/200
# 127/127 [==============================] - 4s 34ms/step - loss: 558.8234 - val_loss: 899.7845
# Epoch 26/200
# 127/127 [==============================] - 4s 35ms/step - loss: 558.9446 - val_loss: 923.0020
# Epoch 27/200
# 127/127 [==============================] - 4s 35ms/step - loss: 558.8986 - val_loss: 874.9647
# Epoch 28/200
# 127/127 [==============================] - 4s 35ms/step - loss: 558.9154 - val_loss: 861.6674
# Epoch 29/200
# 127/127 [==============================] - 4s 35ms/step - loss: 558.6844 - val_loss: 865.3458
# Epoch 30/200
# 127/127 [==============================] - 4s 35ms/step - loss: 558.9023 - val_loss: 885.2340
# Epoch 31/200
# 127/127 [==============================] - ETA: 0s - loss: 559.1891Restoring model weights from the end of the best epoch: 11.
# 127/127 [==============================] - 4s 35ms/step - loss: 559.1891 - val_loss: 906.7233
# Epoch 00031: early stopping
# (9000, 17, 2)
