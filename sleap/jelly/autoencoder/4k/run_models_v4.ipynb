# %%
import sleap
import numpy as np
import matplotlib.pyplot as plt
import os, sys
import datetime

sys.path.append('..')
sys.path.append('../..')
from src.data_loader import *
from min2.run_models import *
from python.postprocess import *
from python.animation import *

# %%
# %load_ext tensorboard

# %% [markdown]
# ## m10

# %%
m10 = get_model_10(window_size=30, pt_cnt=17, num_layers=5, num_heads=16, key_dim=128, value_dim=128)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 30, 34)      1020        ['input_1[0][0]']
#   (LearnablePositionalEncoding2
#  )
#
#  multi_head_attention (MultiHea  (None, 30, 34)      284706      ['learnable_positional_encoding2[
#  dAttention)                                                     0][0]',
#                                                                   'learnable_positional_encoding2[
#                                                                  0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 30, 34)      0           ['learnable_positional_encoding2[
#  da)                                                             0][0]',
#                                                                   'multi_head_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 30, 34)      68          ['tf.__operators__.add[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 30, 512)      17920       ['layer_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 30, 34)       17442       ['dense[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 30, 34)      0           ['layer_normalization[0][0]',
#  mbda)                                                            'dense_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 30, 34)      284706      ['layer_normalization_1[0][0]',
#  eadAttention)                                                    'layer_normalization_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_1[0][0]',
#  mbda)                                                            'multi_head_attention_1[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 30, 512)      17920       ['layer_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 30, 34)       17442       ['dense_2[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_2[0][0]',
#  mbda)                                                            'dense_3[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 30, 34)      284706      ['layer_normalization_3[0][0]',
#  eadAttention)                                                    'layer_normalization_3[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_3[0][0]',
#  mbda)                                                            'multi_head_attention_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_4[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 30, 512)      17920       ['layer_normalization_4[0][0]']
#
#  dense_5 (Dense)                (None, 30, 34)       17442       ['dense_4[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_4[0][0]',
#  mbda)                                                            'dense_5[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 30, 34)      284706      ['layer_normalization_5[0][0]',
#  eadAttention)                                                    'layer_normalization_5[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_5[0][0]',
#  mbda)                                                            'multi_head_attention_3[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_6[0][0]']
#  rmalization)
#
#  dense_6 (Dense)                (None, 30, 512)      17920       ['layer_normalization_6[0][0]']
#
#  dense_7 (Dense)                (None, 30, 34)       17442       ['dense_6[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_6[0][0]',
#  mbda)                                                            'dense_7[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_7[0][0]']
#  rmalization)
#
#  multi_head_attention_4 (MultiH  (None, 30, 34)      284706      ['layer_normalization_7[0][0]',
#  eadAttention)                                                    'layer_normalization_7[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_7[0][0]',
#  mbda)                                                            'multi_head_attention_4[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_8[0][0]']
#  rmalization)
#
#  dense_8 (Dense)                (None, 30, 512)      17920       ['layer_normalization_8[0][0]']
#
#  dense_9 (Dense)                (None, 30, 34)       17442       ['dense_8[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_8[0][0]',
#  mbda)                                                            'dense_9[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_9[0][0]']
#  rmalization)
#
#  tf.__operators__.getitem (Slic  (None, 34)          0           ['layer_normalization_9[0][0]']
#  ingOpLambda)
#
#  dense_10 (Dense)               (None, 34)           1190        ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  reshape (Reshape)              (None, 17, 2)        0           ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 1,603,230
# Trainable params: 1,603,230
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### t1

# %%
# %load_ext tensorboard

# %%
prediction_m10t1 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(1e-4), num_layers=5, 
                              window_size=30, dropout_rate=0, swap_rate=0, roll=True, model=m10)
print(prediction_m10t1.shape)
np.save('../results/r4/prediction_m10t1.npy', prediction_m10t1)
# Out:
# coords_corrected_windows.shape: (9000, 30, 17, 2)
# coords_augmented_windows.shape: (153000, 30, 17, 2)
# X min = 0.11, X max = 0.87
# y min = 0.11, y max = 0.87
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 30, 34)      1020        ['input_1[0][0]']
#   (LearnablePositionalEncoding2
#  )
#
#  multi_head_attention (MultiHea  (None, 30, 34)      284706      ['learnable_positional_encoding2[
#  dAttention)                                                     0][0]',
#                                                                   'learnable_positional_encoding2[
#                                                                  0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 30, 34)      0           ['learnable_positional_encoding2[
#  da)                                                             0][0]',
#                                                                   'multi_head_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 30, 34)      68          ['tf.__operators__.add[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 30, 512)      17920       ['layer_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 30, 34)       17442       ['dense[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 30, 34)      0           ['layer_normalization[0][0]',
#  mbda)                                                            'dense_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 30, 34)      284706      ['layer_normalization_1[0][0]',
#  eadAttention)                                                    'layer_normalization_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_1[0][0]',
#  mbda)                                                            'multi_head_attention_1[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 30, 512)      17920       ['layer_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 30, 34)       17442       ['dense_2[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_2[0][0]',
#  mbda)                                                            'dense_3[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 30, 34)      284706      ['layer_normalization_3[0][0]',
#  eadAttention)                                                    'layer_normalization_3[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_3[0][0]',
#  mbda)                                                            'multi_head_attention_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_4[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 30, 512)      17920       ['layer_normalization_4[0][0]']
#
#  dense_5 (Dense)                (None, 30, 34)       17442       ['dense_4[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_4[0][0]',
#  mbda)                                                            'dense_5[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 30, 34)      284706      ['layer_normalization_5[0][0]',
#  eadAttention)                                                    'layer_normalization_5[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_5[0][0]',
#  mbda)                                                            'multi_head_attention_3[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_6[0][0]']
#  rmalization)
#
#  dense_6 (Dense)                (None, 30, 512)      17920       ['layer_normalization_6[0][0]']
#
#  dense_7 (Dense)                (None, 30, 34)       17442       ['dense_6[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_6[0][0]',
#  mbda)                                                            'dense_7[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_7[0][0]']
#  rmalization)
#
#  multi_head_attention_4 (MultiH  (None, 30, 34)      284706      ['layer_normalization_7[0][0]',
#  eadAttention)                                                    'layer_normalization_7[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_7[0][0]',
#  mbda)                                                            'multi_head_attention_4[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_8[0][0]']
#  rmalization)
#
#  dense_8 (Dense)                (None, 30, 512)      17920       ['layer_normalization_8[0][0]']
#
#  dense_9 (Dense)                (None, 30, 34)       17442       ['dense_8[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_8[0][0]',
#  mbda)                                                            'dense_9[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_9[0][0]']
#  rmalization)
#
#  tf.__operators__.getitem (Slic  (None, 34)          0           ['layer_normalization_9[0][0]']
#  ingOpLambda)
#
#  dense_10 (Dense)               (None, 34)           1190        ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  reshape (Reshape)              (None, 17, 2)        0           ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 1,603,230
# Trainable params: 1,603,230
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Layer LearnablePositionalEncoding2 has arguments ['self', 'window_size', 'pt_cnt']
# in `__init__` and therefore must override `get_config()`.
#
# Example:
#
# class CustomLayer(keras.layers.Layer):
#     def __init__(self, arg1, arg2):
#         super().__init__()
#         self.arg1 = arg1
#         self.arg2 = arg2
#
#     def get_config(self):
#         config = super().get_config()
#         config.update({
#             "arg1": self.arg1,
#             "arg2": self.arg2,
#         })
#         return config
# Epoch 1/200
# 2025-03-11 02:11:24.337217: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2025-03-11 02:11:24.337288: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at matmul_op_impl.h:442 : INTERNAL: Attempting to perform BLAS operation using StreamExecutor without BLAS support
# 2025-03-11 02:11:24.338547: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2025-03-11 02:11:24.338571: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at matmul_op_impl.h:442 : INTERNAL: Attempting to perform BLAS operation using StreamExecutor without BLAS support
# 2025-03-11 02:11:24.339553: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2025-03-11 02:11:24.339572: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at matmul_op_impl.h:442 : INTERNAL: Attempting to perform BLAS operation using StreamExecutor without BLAS support
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /tmp/ipykernel_258559/4024395399.py in <module>
#       1 prediction_m10t1 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(1e-4), num_layers=5,
# ----> 2                               window_size=30, dropout_rate=0, swap_rate=0, roll=True, model=m10)
#       3 print(prediction_m10t1.shape)
#       4 np.save('../results/r4/prediction_m10t1.npy', prediction_m10t1)
#
# ~/Desktop/jelly-sleap/sleap/jelly/autoencoder/min2/run_models.py in run_model_10(window_size, epochs, batch_size, optimizer, split_size, num_layers, shuffle, dropout_rate, swap_rate, roll, model)
#     342               epochs=epochs, batch_size=batch_size,
#     343               validation_data=(X_val, y_val),
# --> 344               callbacks=[tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True, verbose=1), tensorboard_callback])
#     345
#     346     denoised_coords = model.predict(X)
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57     ctx.ensure_initialized()
#      58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#      61     if name is not None:
#
# InternalError:  Attempting to perform BLAS operation using StreamExecutor without BLAS support
# 	 [[node model/multi_head_attention/key/einsum/Einsum
#  (defined at /home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/layers/einsum_dense.py:187)
# ]] [Op:__inference_train_function_6872]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node model/multi_head_attention/key/einsum/Einsum:
# In[0] model/learnable_positional_encoding2/add (defined at ../min2/models.py:349)
# In[1] model/multi_head_attention/key/einsum/Einsum/ReadVariableOp:
#
# Operation defined at: (most recent call last)
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/runpy.py", line 193, in _run_module_as_main
# >>>     "__main__", mod_spec)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/runpy.py", line 85, in _run_code
# >>>     exec(code, run_globals)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel_launcher.py", line 17, in <module>
# >>>     app.launch_new_instance()
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/traitlets/config/application.py", line 1043, in launch_instance
# >>>     app.start()
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 712, in start
# >>>     self.io_loop.start()
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 215, in start
# >>>     self.asyncio_loop.run_forever()
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
# >>>     self._run_once()
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
# >>>     handle._run()
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/asyncio/events.py", line 88, in _run
# >>>     self._context.run(self._callback, *self._args)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
# >>>     await self.process_one()
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 499, in process_one
# >>>     await dispatch(*args)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
# >>>     await result
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
# >>>     reply_content = await reply_content
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 387, in do_execute
# >>>     cell_id=cell_id,
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
# >>>     return super().run_cell(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2976, in run_cell
# >>>     raw_cell, store_history, silent, shell_futures, cell_id
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
# >>>     return runner(coro)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
# >>>     coro.send(None)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3258, in run_cell_async
# >>>     interactivity=interactivity, compiler=compiler, result=result)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
# >>>     if (await self.run_code(code, result,  async_=asy)):
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
# >>>     exec(code_obj, self.user_global_ns, self.user_ns)
# >>>
# >>>   File "/tmp/ipykernel_258559/4024395399.py", line 2, in <module>
# >>>     window_size=30, dropout_rate=0, swap_rate=0, roll=True, model=m10)
# >>>
# >>>   File "../min2/run_models.py", line 344, in run_model_10
# >>>     callbacks=[tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True, verbose=1), tensorboard_callback])
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/training.py", line 1216, in fit
# >>>     tmp_logs = self.train_function(iterator)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/training.py", line 878, in train_function
# >>>     return step_function(self, iterator)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/training.py", line 867, in step_function
# >>>     outputs = model.distribute_strategy.run(run_step, args=(data,))
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/training.py", line 860, in run_step
# >>>     outputs = model.train_step(data)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/training.py", line 808, in train_step
# >>>     y_pred = self(x, training=True)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/functional.py", line 452, in call
# >>>     inputs, training=training, mask=mask)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/functional.py", line 589, in _run_internal_graph
# >>>     outputs = node.layer(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/layers/multi_head_attention.py", line 498, in call
# >>>     key = self._key_dense(key)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/layers/einsum_dense.py", line 187, in call
# >>>     ret = tf.einsum(self.equation, inputs, self.kernel)
# >>>

# %% [markdown]
# ## m11

# %% [markdown]
# ### t1

# %%
m11 = get_model_11(window_size=30, pt_cnt=17, latent_dim=128, num_layers=4)
tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 30, 34)]          0
#
#  dense_11 (Dense)            (None, 30, 2048)          71680
#
#  dense_12 (Dense)            (None, 30, 1024)          2098176
#
#  dense_13 (Dense)            (None, 30, 512)           524800
#
#  dense_14 (Dense)            (None, 30, 256)           131328
#
#  dense_15 (Dense)            (None, 30, 128)           32896
#
#  dense_16 (Dense)            (None, 30, 128)           16512
#
#  dense_17 (Dense)            (None, 30, 256)           33024
#
#  dense_18 (Dense)            (None, 30, 512)           131584
#
#  dense_19 (Dense)            (None, 30, 1024)          525312
#
#  tf.__operators__.getitem_1   (None, 1024)             0
#  (SlicingOpLambda)
#
#  dense_20 (Dense)            (None, 34)                34850
#
# =================================================================
# Total params: 3,600,162
# Trainable params: 3,600,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction_m11t1 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4), num_layers=4, 
                              window_size=30, dropout_rate=0, swap_rate=0, roll=True, model=m11)
print(prediction_m11t1.shape)
np.save('../results/r4/prediction_m11t1.npy', prediction_m11t1)
# Out:
# coords_corrected_windows.shape: (9000, 30, 34)
# coords_augmented_windows.shape: (153000, 30, 34)
# X min = 0.11, X max = 0.87
# y min = 0.11, y max = 0.87
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 30, 34)]          0
#
#  dense_11 (Dense)            (None, 30, 2048)          71680
#
#  dense_12 (Dense)            (None, 30, 1024)          2098176
#
#  dense_13 (Dense)            (None, 30, 512)           524800
#
#  dense_14 (Dense)            (None, 30, 256)           131328
#
#  dense_15 (Dense)            (None, 30, 128)           32896
#
#  dense_16 (Dense)            (None, 30, 128)           16512
#
#  dense_17 (Dense)            (None, 30, 256)           33024
#
#  dense_18 (Dense)            (None, 30, 512)           131584
#
#  dense_19 (Dense)            (None, 30, 1024)          525312
#
#  tf.__operators__.getitem_1   (None, 1024)             0
#  (SlicingOpLambda)
#
#  dense_20 (Dense)            (None, 34)                34850
#
# =================================================================
# Total params: 3,600,162
# Trainable params: 3,600,162
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 2025-03-11 02:13:22.025440: E tensorflow/stream_executor/cuda/cuda_blas.cc:226] failed to create cublas handle: CUBLAS_STATUS_NOT_INITIALIZED
# 2025-03-11 02:13:22.025514: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at matmul_op_impl.h:442 : INTERNAL: Attempting to perform BLAS operation using StreamExecutor without BLAS support
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /tmp/ipykernel_258559/2850209933.py in <module>
#       1 prediction_m11t1 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4), num_layers=4,
# ----> 2                               window_size=30, dropout_rate=0, swap_rate=0, roll=True, model=m11)
#       3 print(prediction_m11t1.shape)
#       4 np.save('../results/r4/prediction_m11t1.npy', prediction_m11t1)
#
# ~/Desktop/jelly-sleap/sleap/jelly/autoencoder/min2/run_models.py in run_model_11(window_size, epochs, batch_size, optimizer, split_size, num_layers, shuffle, dropout_rate, swap_rate, roll, model, latent_dim, flatten)
#     382               epochs=epochs, batch_size=batch_size,
#     383               validation_data=(X_val, y_val),
# --> 384               callbacks=[tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True, verbose=1), tensorboard_callback])
#     385
#     386     denoised_coords = model.predict(X)
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57     ctx.ensure_initialized()
#      58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#      61     if name is not None:
#
# InternalError:  Attempting to perform BLAS operation using StreamExecutor without BLAS support
# 	 [[node model_1/dense_11/Tensordot/MatMul
#  (defined at /home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/layers/core/dense.py:202)
# ]] [Op:__inference_train_function_8914]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node model_1/dense_11/Tensordot/MatMul:
# In[0] model_1/dense_11/Tensordot/Reshape:
# In[1] model_1/dense_11/Tensordot/ReadVariableOp:
#
# Operation defined at: (most recent call last)
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/runpy.py", line 193, in _run_module_as_main
# >>>     "__main__", mod_spec)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/runpy.py", line 85, in _run_code
# >>>     exec(code, run_globals)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel_launcher.py", line 17, in <module>
# >>>     app.launch_new_instance()
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/traitlets/config/application.py", line 1043, in launch_instance
# >>>     app.start()
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 712, in start
# >>>     self.io_loop.start()
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 215, in start
# >>>     self.asyncio_loop.run_forever()
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
# >>>     self._run_once()
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
# >>>     handle._run()
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/asyncio/events.py", line 88, in _run
# >>>     self._context.run(self._callback, *self._args)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
# >>>     await self.process_one()
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 499, in process_one
# >>>     await dispatch(*args)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
# >>>     await result
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
# >>>     reply_content = await reply_content
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 387, in do_execute
# >>>     cell_id=cell_id,
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
# >>>     return super().run_cell(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2976, in run_cell
# >>>     raw_cell, store_history, silent, shell_futures, cell_id
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
# >>>     return runner(coro)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
# >>>     coro.send(None)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3258, in run_cell_async
# >>>     interactivity=interactivity, compiler=compiler, result=result)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
# >>>     if (await self.run_code(code, result,  async_=asy)):
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
# >>>     exec(code_obj, self.user_global_ns, self.user_ns)
# >>>
# >>>   File "/tmp/ipykernel_258559/2850209933.py", line 2, in <module>
# >>>     window_size=30, dropout_rate=0, swap_rate=0, roll=True, model=m11)
# >>>
# >>>   File "../min2/run_models.py", line 384, in run_model_11
# >>>     callbacks=[tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True, verbose=1), tensorboard_callback])
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/training.py", line 1216, in fit
# >>>     tmp_logs = self.train_function(iterator)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/training.py", line 878, in train_function
# >>>     return step_function(self, iterator)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/training.py", line 867, in step_function
# >>>     outputs = model.distribute_strategy.run(run_step, args=(data,))
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/training.py", line 860, in run_step
# >>>     outputs = model.train_step(data)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/training.py", line 808, in train_step
# >>>     y_pred = self(x, training=True)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/functional.py", line 452, in call
# >>>     inputs, training=training, mask=mask)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/functional.py", line 589, in _run_internal_graph
# >>>     outputs = node.layer(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/layers/core/dense.py", line 202, in call
# >>>     outputs = tf.tensordot(inputs, self.kernel, [[rank - 1], [0]])
# >>>

# %% [markdown]
# ### t2

# %%
m11 = get_model_11(window_size=30, pt_cnt=17, latent_dim=512, num_layers=4)
tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 30, 34)]          0
#
#  dense_11 (Dense)            (None, 30, 8192)          286720
#
#  dense_12 (Dense)            (None, 30, 4096)          33558528
#
#  dense_13 (Dense)            (None, 30, 2048)          8390656
#
#  dense_14 (Dense)            (None, 30, 1024)          2098176
#
#  dense_15 (Dense)            (None, 30, 512)           524800
#
#  dense_16 (Dense)            (None, 30, 512)           262656
#
#  dense_17 (Dense)            (None, 30, 1024)          525312
#
#  dense_18 (Dense)            (None, 30, 2048)          2099200
#
#  dense_19 (Dense)            (None, 30, 4096)          8392704
#
#  tf.__operators__.getitem_1   (None, 4096)             0
#  (SlicingOpLambda)
#
#  dense_20 (Dense)            (None, 34)                139298
#
# =================================================================
# Total params: 56,278,050
# Trainable params: 56,278,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction_m11t2 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4), 
                              window_size=30, dropout_rate=0, swap_rate=0, roll=True, model=m11)
print(prediction_m11t2.shape)
np.save('../results/r4/prediction_m11t2.npy', prediction_m11t2)
# Out:
# coords_corrected_windows.shape: (9000, 30, 34)
# coords_augmented_windows.shape: (153000, 30, 34)
# X min = 0.11, X max = 0.87
# y min = 0.11, y max = 0.87
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 30, 34)]          0
#
#  dense_11 (Dense)            (None, 30, 8192)          286720
#
#  dense_12 (Dense)            (None, 30, 4096)          33558528
#
#  dense_13 (Dense)            (None, 30, 2048)          8390656
#
#  dense_14 (Dense)            (None, 30, 1024)          2098176
#
#  dense_15 (Dense)            (None, 30, 512)           524800
#
#  dense_16 (Dense)            (None, 30, 512)           262656
#
#  dense_17 (Dense)            (None, 30, 1024)          525312
#
#  dense_18 (Dense)            (None, 30, 2048)          2099200
#
#  dense_19 (Dense)            (None, 30, 4096)          8392704
#
#  tf.__operators__.getitem_1   (None, 4096)             0
#  (SlicingOpLambda)
#
#  dense_20 (Dense)            (None, 34)                139298
#
# =================================================================
# Total params: 56,278,050
# Trainable params: 56,278,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 2025-03-11 01:57:03.110214: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (GPU_0_bfc) ran out of memory trying to allocate 128.00MiB (rounded to 134217728)requested by op Fill
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2025-03-11 01:57:03.111151: W tensorflow/core/common_runtime/bfc_allocator.cc:474] **____**____*******************************________**************************__*******************xx
# 2025-03-11 01:57:03.111231: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at constant_op.cc:175 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[8192,4096] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_246808/3128406140.py in <module>
#       1 prediction_m11t2 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4),
# ----> 2                               window_size=30, dropout_rate=0, swap_rate=0, roll=True, model=m11)
#       3 print(prediction_m11t2.shape)
#       4 np.save('../results/r4/prediction_m11t2.npy', prediction_m11t2)
#
# ~/Desktop/jelly-sleap/sleap/jelly/autoencoder/min2/run_models.py in run_model_11(window_size, epochs, batch_size, optimizer, split_size, num_layers, shuffle, dropout_rate, swap_rate, roll, model, latent_dim, flatten)
#     382               epochs=epochs, batch_size=batch_size,
#     383               validation_data=(X_val, y_val),
# --> 384               callbacks=[tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True, verbose=1), tensorboard_callback])
#     385
#     386     denoised_coords = model.predict(X)
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# -> 1129               raise e.ag_error_metadata.to_exception(e)
#    1130             else:
#    1131               raise
#
# ResourceExhaustedError: in user code:
#
#     File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/engine/training.py", line 816, in train_step
#         self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py", line 532, in minimize
#         return self.apply_gradients(grads_and_vars, name=name)
#     File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py", line 639, in apply_gradients
#         self._create_all_weights(var_list)
#     File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py", line 830, in _create_all_weights
#         self._create_slots(var_list)
#     File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/optimizer_v2/adam.py", line 117, in _create_slots
#         self.add_slot(var, 'm')
#     File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py", line 920, in add_slot
#         initial_value=initial_value)
#     File "/home/mingxiao/micromamba/envs/sleap/lib/python3.7/site-packages/keras/initializers/initializers_v2.py", line 144, in __call__
#         return tf.zeros(shape, dtype)
#
#     ResourceExhaustedError: OOM when allocating tensor with shape[8192,4096] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Fill]

# %% [markdown]
# ### t3

# %%
m11 = get_model_11(window_size=30, pt_cnt=17, latent_dim=64, num_layers=2)
tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 30, 34)]          0
#
#  dense_45 (Dense)            (None, 30, 128)           4480
#
#  dense_46 (Dense)            (None, 30, 64)            8256
#
#  dense_47 (Dense)            (None, 30, 64)            4160
#
#  dense_48 (Dense)            (None, 30, 128)           8320
#
#  tf.__operators__.getitem_4   (None, 128)              0
#  (SlicingOpLambda)
#
#  dense_49 (Dense)            (None, 34)                4386
#
# =================================================================
# Total params: 29,602
# Trainable params: 29,602
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction_m11t3 = run_model_11(epochs=200, batch_size=64, optimizer=Adam(1e-4), 
                              window_size=30, dropout_rate=0.01, swap_rate=0.01, roll=True, model=m11)
print(prediction_m11t3.shape)
np.save('../results/r4/prediction_m11t3.npy', prediction_m11t3)
# Out:
# coords_corrected_windows.shape: (9000, 30, 34)
# coords_augmented_windows.shape: (153000, 30, 34)
# X min = 0.11, X max = 0.87
# y min = 0.11, y max = 0.87
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 30, 34)]          0
#
#  dense_45 (Dense)            (None, 30, 128)           4480
#
#  dense_46 (Dense)            (None, 30, 64)            8256
#
#  dense_47 (Dense)            (None, 30, 64)            4160
#
#  dense_48 (Dense)            (None, 30, 128)           8320
#
#  tf.__operators__.getitem_4   (None, 128)              0
#  (SlicingOpLambda)
#
#  dense_49 (Dense)            (None, 34)                4386
#
# =================================================================
# Total params: 29,602
# Trainable params: 29,602
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0295
# Epoch 2/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0297
# Epoch 3/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0302
# Epoch 4/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0305
# Epoch 5/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0295
# Epoch 6/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0307
# Epoch 7/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0296
# Epoch 8/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0295
# Epoch 9/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0297
# Epoch 10/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0299
# Epoch 11/200
# 127/127 [==============================] - 1s 8ms/step - loss: 0.0189 - val_loss: 0.0303
# Epoch 12/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0304
# Epoch 13/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0305
# Epoch 14/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0298
# Epoch 15/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0298
# Epoch 16/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0304
# Epoch 17/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0289
# Epoch 18/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0298
# Epoch 19/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0302
# Epoch 20/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0305
# Epoch 21/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0289
# Epoch 22/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0301
# Epoch 23/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0297
# Epoch 24/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0297
# Epoch 25/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0298
# Epoch 26/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0307
# Epoch 27/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0301
# Epoch 28/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0302
# Epoch 29/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 30/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0301
# Epoch 31/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0290
# Epoch 32/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 33/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0291
# Epoch 34/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0296
# Epoch 35/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0299
# Epoch 36/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0303
# Epoch 37/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0301
# Epoch 38/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0298
# Epoch 39/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0297
# Epoch 40/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0296
# Epoch 41/200
# 125/127 [============================>.] - ETA: 0s - loss: 0.0189Restoring model weights from the end of the best epoch: 21.
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 00041: early stopping
# (9000, 17, 2)

# %% [markdown]
# ### t4
