# %%
import sleap
import numpy as np
import matplotlib.pyplot as plt
import os, sys
import datetime

sys.path.append('..')
sys.path.append('../..')
from src.data_loader import *
from min2.run_models import *
from python.postprocess import *
from python.animation import *

# %%
# %load_ext tensorboard

# %% [markdown]
# ## m10

# %%
m10 = get_model_10(window_size=30, pt_cnt=17, num_layers=5, num_heads=16, key_dim=128, value_dim=128)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 30, 34)      1020        ['input_1[0][0]']
#   (LearnablePositionalEncoding2
#  )
#
#  multi_head_attention (MultiHea  (None, 30, 34)      284706      ['learnable_positional_encoding2[
#  dAttention)                                                     0][0]',
#                                                                   'learnable_positional_encoding2[
#                                                                  0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 30, 34)      0           ['learnable_positional_encoding2[
#  da)                                                             0][0]',
#                                                                   'multi_head_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 30, 34)      68          ['tf.__operators__.add[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 30, 512)      17920       ['layer_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 30, 34)       17442       ['dense[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 30, 34)      0           ['layer_normalization[0][0]',
#  mbda)                                                            'dense_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 30, 34)      284706      ['layer_normalization_1[0][0]',
#  eadAttention)                                                    'layer_normalization_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_1[0][0]',
#  mbda)                                                            'multi_head_attention_1[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 30, 512)      17920       ['layer_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 30, 34)       17442       ['dense_2[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_2[0][0]',
#  mbda)                                                            'dense_3[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 30, 34)      284706      ['layer_normalization_3[0][0]',
#  eadAttention)                                                    'layer_normalization_3[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_3[0][0]',
#  mbda)                                                            'multi_head_attention_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_4[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 30, 512)      17920       ['layer_normalization_4[0][0]']
#
#  dense_5 (Dense)                (None, 30, 34)       17442       ['dense_4[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_4[0][0]',
#  mbda)                                                            'dense_5[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 30, 34)      284706      ['layer_normalization_5[0][0]',
#  eadAttention)                                                    'layer_normalization_5[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_5[0][0]',
#  mbda)                                                            'multi_head_attention_3[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_6[0][0]']
#  rmalization)
#
#  dense_6 (Dense)                (None, 30, 512)      17920       ['layer_normalization_6[0][0]']
#
#  dense_7 (Dense)                (None, 30, 34)       17442       ['dense_6[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_6[0][0]',
#  mbda)                                                            'dense_7[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_7[0][0]']
#  rmalization)
#
#  multi_head_attention_4 (MultiH  (None, 30, 34)      284706      ['layer_normalization_7[0][0]',
#  eadAttention)                                                    'layer_normalization_7[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_7[0][0]',
#  mbda)                                                            'multi_head_attention_4[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_8[0][0]']
#  rmalization)
#
#  dense_8 (Dense)                (None, 30, 512)      17920       ['layer_normalization_8[0][0]']
#
#  dense_9 (Dense)                (None, 30, 34)       17442       ['dense_8[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_8[0][0]',
#  mbda)                                                            'dense_9[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_9[0][0]']
#  rmalization)
#
#  tf.__operators__.getitem (Slic  (None, 34)          0           ['layer_normalization_9[0][0]']
#  ingOpLambda)
#
#  dense_10 (Dense)               (None, 34)           1190        ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  reshape (Reshape)              (None, 17, 2)        0           ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 1,603,230
# Trainable params: 1,603,230
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(m10, to_file='m10.png', show_shapes=True, show_layer_names=True, expand_nested=True)

# %% [markdown]
# ### t1

# %%
# %load_ext tensorboard

# %%
prediction_m10t1 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(1e-4), num_layers=5, 
                              window_size=30, dropout_rate=0, swap_rate=0, roll=True, model=m10)
print(prediction_m10t1.shape)
np.save('../results/r4/prediction_m10t3.npy', prediction_m10t1)
# Out:
# coords_corrected_windows.shape: (9000, 30, 17, 2)
# coords_augmented_windows.shape: (153000, 30, 17, 2)
# X min = 0.11, X max = 0.87
# y min = 0.11, y max = 0.87
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 30, 34)      1020        ['input_1[0][0]']
#   (LearnablePositionalEncoding2
#  )
#
#  multi_head_attention (MultiHea  (None, 30, 34)      284706      ['learnable_positional_encoding2[
#  dAttention)                                                     0][0]',
#                                                                   'learnable_positional_encoding2[
#                                                                  0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 30, 34)      0           ['learnable_positional_encoding2[
#  da)                                                             0][0]',
#                                                                   'multi_head_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 30, 34)      68          ['tf.__operators__.add[0][0]']
#  alization)
#
#  dense (Dense)                  (None, 30, 512)      17920       ['layer_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 30, 34)       17442       ['dense[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 30, 34)      0           ['layer_normalization[0][0]',
#  mbda)                                                            'dense_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 30, 34)      284706      ['layer_normalization_1[0][0]',
#  eadAttention)                                                    'layer_normalization_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_1[0][0]',
#  mbda)                                                            'multi_head_attention_1[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  dense_2 (Dense)                (None, 30, 512)      17920       ['layer_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 30, 34)       17442       ['dense_2[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_2[0][0]',
#  mbda)                                                            'dense_3[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 30, 34)      284706      ['layer_normalization_3[0][0]',
#  eadAttention)                                                    'layer_normalization_3[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_3[0][0]',
#  mbda)                                                            'multi_head_attention_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_4[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 30, 512)      17920       ['layer_normalization_4[0][0]']
#
#  dense_5 (Dense)                (None, 30, 34)       17442       ['dense_4[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_4[0][0]',
#  mbda)                                                            'dense_5[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 30, 34)      284706      ['layer_normalization_5[0][0]',
#  eadAttention)                                                    'layer_normalization_5[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_5[0][0]',
#  mbda)                                                            'multi_head_attention_3[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_6[0][0]']
#  rmalization)
#
#  dense_6 (Dense)                (None, 30, 512)      17920       ['layer_normalization_6[0][0]']
#
#  dense_7 (Dense)                (None, 30, 34)       17442       ['dense_6[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_6[0][0]',
#  mbda)                                                            'dense_7[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_7[0][0]']
#  rmalization)
#
#  multi_head_attention_4 (MultiH  (None, 30, 34)      284706      ['layer_normalization_7[0][0]',
#  eadAttention)                                                    'layer_normalization_7[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_7[0][0]',
#  mbda)                                                            'multi_head_attention_4[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_8[0][0]']
#  rmalization)
#
#  dense_8 (Dense)                (None, 30, 512)      17920       ['layer_normalization_8[0][0]']
#
#  dense_9 (Dense)                (None, 30, 34)       17442       ['dense_8[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 30, 34)      0           ['layer_normalization_8[0][0]',
#  mbda)                                                            'dense_9[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 30, 34)      68          ['tf.__operators__.add_9[0][0]']
#  rmalization)
#
#  tf.__operators__.getitem (Slic  (None, 34)          0           ['layer_normalization_9[0][0]']
#  ingOpLambda)
#
#  dense_10 (Dense)               (None, 34)           1190        ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  reshape (Reshape)              (None, 17, 2)        0           ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 1,603,230
# Trainable params: 1,603,230
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring...
# Layer LearnablePositionalEncoding2 has arguments ['self', 'window_size', 'pt_cnt']
# in `__init__` and therefore must override `get_config()`.
#
# Example:
#
# class CustomLayer(keras.layers.Layer):
#     def __init__(self, arg1, arg2):
#         super().__init__()
#         self.arg1 = arg1
#         self.arg2 = arg2
#
#     def get_config(self):
#         config = super().get_config()
#         config.update({
#             "arg1": self.arg1,
#             "arg2": self.arg2,
#         })
#         return config
# Epoch 1/200
# 127/127 [==============================] - 9s 42ms/step - loss: 0.0258 - val_loss: 0.0294
# Epoch 2/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0303
# Epoch 3/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0303
# Epoch 4/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0297
# Epoch 5/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0298
# Epoch 6/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0303
# Epoch 7/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0307
# Epoch 8/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0301
# Epoch 9/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0318
# Epoch 10/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0291
# Epoch 11/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0302
# Epoch 12/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0311
# Epoch 13/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0307
# Epoch 14/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0317
# Epoch 15/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0294
# Epoch 16/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0304
# Epoch 17/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0285
# Epoch 18/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0301
# Epoch 19/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0289
# Epoch 20/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0299
# Epoch 21/200
# 127/127 [==============================] - 5s 36ms/step - loss: 0.0189 - val_loss: 0.0292
# Epoch 22/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0190 - val_loss: 0.0294
# Epoch 23/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0303
# Epoch 24/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0291
# Epoch 25/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 26/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0306
# Epoch 27/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0306
# Epoch 28/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0296
# Epoch 29/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0302
# Epoch 30/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0307
# Epoch 31/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0293
# Epoch 32/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0322
# Epoch 33/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0301
# Epoch 34/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0307
# Epoch 35/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0313
# Epoch 36/200
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 37/200
# 127/127 [==============================] - ETA: 0s - loss: 0.0189Restoring model weights from the end of the best epoch: 17.
# 127/127 [==============================] - 5s 37ms/step - loss: 0.0189 - val_loss: 0.0303
# Epoch 00037: early stopping
# (9000, 17, 2)

# %% [markdown]
# ## m11

# %% [markdown]
# ### t1

# %%
m11 = get_model_11(window_size=30, pt_cnt=17, latent_dim=128, num_layers=4)
tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 30, 34)]          0
#
#  dense_3 (Dense)             (None, 30, 256)           8960
#
#  dense_4 (Dense)             (None, 30, 128)           32896
#
#  dense_5 (Dense)             (None, 30, 128)           16512
#
#  dense_6 (Dense)             (None, 30, 256)           33024
#
#  dense_7 (Dense)             (None, 30, 512)           131584
#
#  dense_8 (Dense)             (None, 30, 1024)          525312
#
#  tf.__operators__.getitem (S  (None, 1024)             0
#  licingOpLambda)
#
#  dense_9 (Dense)             (None, 34)                34850
#
# =================================================================
# Total params: 783,138
# Trainable params: 783,138
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction_m11t1 = run_model_11(epochs=200, batch_size=64, optimizer=Adam(1e-4), num_layers=4, 
                              window_size=30, dropout_rate=0, swap_rate=0, roll=True, model=m11)
print(prediction_m11t1.shape)
np.save('../results/r4/prediction_m11t1.npy', prediction_m11t1)
# Out:
# coords_corrected_windows.shape: (9000, 30, 34)
# coords_augmented_windows.shape: (153000, 30, 34)
# X min = 0.11, X max = 0.87
# y min = 0.11, y max = 0.87
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 30, 34)]          0
#
#  dense_3 (Dense)             (None, 30, 256)           8960
#
#  dense_4 (Dense)             (None, 30, 128)           32896
#
#  dense_5 (Dense)             (None, 30, 128)           16512
#
#  dense_6 (Dense)             (None, 30, 256)           33024
#
#  dense_7 (Dense)             (None, 30, 512)           131584
#
#  dense_8 (Dense)             (None, 30, 1024)          525312
#
#  tf.__operators__.getitem (S  (None, 1024)             0
#  licingOpLambda)
#
#  dense_9 (Dense)             (None, 34)                34850
#
# =================================================================
# Total params: 783,138
# Trainable params: 783,138
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 127/127 [==============================] - 3s 12ms/step - loss: 0.0228 - val_loss: 0.0324
# Epoch 2/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0190 - val_loss: 0.0299
# Epoch 3/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0190 - val_loss: 0.0300
# Epoch 4/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0190 - val_loss: 0.0301
# Epoch 5/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0190 - val_loss: 0.0294
# Epoch 6/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0190 - val_loss: 0.0303
# Epoch 7/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0190 - val_loss: 0.0307
# Epoch 8/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0190 - val_loss: 0.0295
# Epoch 9/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0190 - val_loss: 0.0298
# Epoch 10/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0303
# Epoch 11/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 12/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 13/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0305
# Epoch 14/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0293
# Epoch 15/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0190 - val_loss: 0.0297
# Epoch 16/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0302
# Epoch 17/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0291
# Epoch 18/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0295
# Epoch 19/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0297
# Epoch 20/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0297
# Epoch 21/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0296
# Epoch 22/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0285
# Epoch 23/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0287
# Epoch 24/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0310
# Epoch 25/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0294
# Epoch 26/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 27/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0301
# Epoch 28/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0313
# Epoch 29/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0305
# Epoch 30/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0291
# Epoch 31/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 32/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 33/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0295
# Epoch 34/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0306
# Epoch 35/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0298
# Epoch 36/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0299
# Epoch 37/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0282
# Epoch 38/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0297
# Epoch 39/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0289
# Epoch 40/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0306
# Epoch 41/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0307
# Epoch 42/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0281
# Epoch 43/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0305
# Epoch 44/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0304
# Epoch 45/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0298
# Epoch 46/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 47/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0291
# Epoch 48/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0291
# Epoch 49/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0281
# Epoch 50/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0309
# Epoch 51/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0292
# Epoch 52/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 53/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0294
# Epoch 54/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0299
# Epoch 55/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0296
# Epoch 56/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0283
# Epoch 57/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0299
# Epoch 58/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0295
# Epoch 59/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0295
# Epoch 60/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0296
# Epoch 61/200
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0301
# Epoch 62/200
# 121/127 [===========================>..] - ETA: 0s - loss: 0.0189Restoring model weights from the end of the best epoch: 42.
# 127/127 [==============================] - 1s 10ms/step - loss: 0.0189 - val_loss: 0.0307
# Epoch 00062: early stopping
# (9000, 17, 2)

# %% [markdown]
# ### t2

# %%
m11 = get_model_11(window_size=30, pt_cnt=17, latent_dim=512, num_layers=4)
tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 30, 34)]          0
#
#  dense_13 (Dense)            (None, 30, 1024)          35840
#
#  dense_14 (Dense)            (None, 30, 512)           524800
#
#  dense_15 (Dense)            (None, 30, 512)           262656
#
#  dense_16 (Dense)            (None, 30, 1024)          525312
#
#  dense_17 (Dense)            (None, 30, 2048)          2099200
#
#  dense_18 (Dense)            (None, 30, 4096)          8392704
#
#  tf.__operators__.getitem_1   (None, 4096)             0
#  (SlicingOpLambda)
#
#  dense_19 (Dense)            (None, 34)                139298
#
# =================================================================
# Total params: 11,979,810
# Trainable params: 11,979,810
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction_m11t2 = run_model_11(epochs=200, batch_size=64, optimizer=Adam(1e-4), 
                              window_size=30, dropout_rate=0, swap_rate=0, roll=True, model=m11)
print(prediction_m11t2.shape)
np.save('../results/r4/prediction_m11t2.npy', prediction_m11t2)
# Out:
# coords_corrected_windows.shape: (9000, 30, 34)
# coords_augmented_windows.shape: (153000, 30, 34)
# X min = 0.11, X max = 0.87
# y min = 0.11, y max = 0.87
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 30, 34)]          0
#
#  dense_13 (Dense)            (None, 30, 1024)          35840
#
#  dense_14 (Dense)            (None, 30, 512)           524800
#
#  dense_15 (Dense)            (None, 30, 512)           262656
#
#  dense_16 (Dense)            (None, 30, 1024)          525312
#
#  dense_17 (Dense)            (None, 30, 2048)          2099200
#
#  dense_18 (Dense)            (None, 30, 4096)          8392704
#
#  tf.__operators__.getitem_1   (None, 4096)             0
#  (SlicingOpLambda)
#
#  dense_19 (Dense)            (None, 34)                139298
#
# =================================================================
# Total params: 11,979,810
# Trainable params: 11,979,810
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0206 - val_loss: 0.0295
# Epoch 2/200
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0190 - val_loss: 0.0317
# Epoch 3/200
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0190 - val_loss: 0.0305
# Epoch 4/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0190 - val_loss: 0.0296
# Epoch 5/200
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0190 - val_loss: 0.0282
# Epoch 6/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0190 - val_loss: 0.0320
# Epoch 7/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0190 - val_loss: 0.0294
# Epoch 8/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0190 - val_loss: 0.0317
# Epoch 9/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0190 - val_loss: 0.0313
# Epoch 10/200
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0190 - val_loss: 0.0272
# Epoch 11/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0190 - val_loss: 0.0289
# Epoch 12/200
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0189 - val_loss: 0.0307
# Epoch 13/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0190 - val_loss: 0.0306
# Epoch 14/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0189 - val_loss: 0.0294
# Epoch 15/200
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0189 - val_loss: 0.0294
# Epoch 16/200
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0189 - val_loss: 0.0302
# Epoch 17/200
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0189 - val_loss: 0.0306
# Epoch 18/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0189 - val_loss: 0.0310
# Epoch 19/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0189 - val_loss: 0.0292
# Epoch 20/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0189 - val_loss: 0.0308
# Epoch 21/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 22/200
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0189 - val_loss: 0.0298
# Epoch 23/200
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0189 - val_loss: 0.0295
# Epoch 24/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0189 - val_loss: 0.0289
# Epoch 25/200
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0189 - val_loss: 0.0299
# Epoch 26/200
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0189 - val_loss: 0.0308
# Epoch 27/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0189 - val_loss: 0.0289
# Epoch 28/200
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0189 - val_loss: 0.0301
# Epoch 29/200
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0189 - val_loss: 0.0299
# Epoch 30/200
# 126/127 [============================>.] - ETA: 0s - loss: 0.0189Restoring model weights from the end of the best epoch: 10.
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0189 - val_loss: 0.0290
# Epoch 00030: early stopping
# (9000, 17, 2)

# %% [markdown]
# ### t3

# %%
m11 = get_model_11(window_size=30, pt_cnt=17, latent_dim=64, num_layers=2)
tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 30, 34)]          0
#
#  dense_45 (Dense)            (None, 30, 128)           4480
#
#  dense_46 (Dense)            (None, 30, 64)            8256
#
#  dense_47 (Dense)            (None, 30, 64)            4160
#
#  dense_48 (Dense)            (None, 30, 128)           8320
#
#  tf.__operators__.getitem_4   (None, 128)              0
#  (SlicingOpLambda)
#
#  dense_49 (Dense)            (None, 34)                4386
#
# =================================================================
# Total params: 29,602
# Trainable params: 29,602
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction_m11t3 = run_model_11(epochs=200, batch_size=64, optimizer=Adam(1e-4), 
                              window_size=30, dropout_rate=0.01, swap_rate=0.01, roll=True, model=m11)
print(prediction_m11t3.shape)
np.save('../results/r4/prediction_m11t3.npy', prediction_m11t3)
# Out:
# coords_corrected_windows.shape: (9000, 30, 34)
# coords_augmented_windows.shape: (153000, 30, 34)
# X min = 0.11, X max = 0.87
# y min = 0.11, y max = 0.87
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 30, 34)]          0
#
#  dense_45 (Dense)            (None, 30, 128)           4480
#
#  dense_46 (Dense)            (None, 30, 64)            8256
#
#  dense_47 (Dense)            (None, 30, 64)            4160
#
#  dense_48 (Dense)            (None, 30, 128)           8320
#
#  tf.__operators__.getitem_4   (None, 128)              0
#  (SlicingOpLambda)
#
#  dense_49 (Dense)            (None, 34)                4386
#
# =================================================================
# Total params: 29,602
# Trainable params: 29,602
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 127/127 [==============================] - 1s 9ms/step - loss: 0.0189 - val_loss: 0.0295
# Epoch 2/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0297
# Epoch 3/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0302
# Epoch 4/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0305
# Epoch 5/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0295
# Epoch 6/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0307
# Epoch 7/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0296
# Epoch 8/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0295
# Epoch 9/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0297
# Epoch 10/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0299
# Epoch 11/200
# 127/127 [==============================] - 1s 8ms/step - loss: 0.0189 - val_loss: 0.0303
# Epoch 12/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0304
# Epoch 13/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0305
# Epoch 14/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0298
# Epoch 15/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0298
# Epoch 16/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0304
# Epoch 17/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0289
# Epoch 18/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0298
# Epoch 19/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0302
# Epoch 20/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0305
# Epoch 21/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0289
# Epoch 22/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0301
# Epoch 23/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0297
# Epoch 24/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0297
# Epoch 25/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0298
# Epoch 26/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0307
# Epoch 27/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0301
# Epoch 28/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0302
# Epoch 29/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 30/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0301
# Epoch 31/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0290
# Epoch 32/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 33/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0291
# Epoch 34/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0296
# Epoch 35/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0299
# Epoch 36/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0303
# Epoch 37/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0301
# Epoch 38/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0298
# Epoch 39/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0297
# Epoch 40/200
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0296
# Epoch 41/200
# 125/127 [============================>.] - ETA: 0s - loss: 0.0189Restoring model weights from the end of the best epoch: 21.
# 127/127 [==============================] - 1s 7ms/step - loss: 0.0189 - val_loss: 0.0300
# Epoch 00041: early stopping
# (9000, 17, 2)

# %% [markdown]
# ### t4
