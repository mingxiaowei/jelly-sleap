# %%
import sleap
import numpy as np
import matplotlib.pyplot as plt
import os, sys
import datetime

sys.path.append('..')
sys.path.append('../..')
from src.data_loader import *
from min2.run_models import *
from python.postprocess import *
from python.animation import *

# %% [markdown]
# # m10

# %% [markdown]
# ## t1

# %%
m10 = get_model_10(window_size=50, pt_cnt=17, num_layers=5, num_heads=16, key_dim=128, value_dim=128)
prediction_m10t1 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(1e-4), num_layers=5, 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, model=m10)
print(prediction_m10t1.shape)
np.save('../results/r7/prediction_m10t1.npy', prediction_m10t1)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 50, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 50, 34)      1700        ['input_1[0][0]']
#   (LearnablePositionalEncoding2
#  )
#
#  multi_head_attention (MultiHea  (None, 50, 34)      284706      ['learnable_positional_encoding2[
#  dAttention)                                                     0][0]',
#                                                                   'learnable_positional_encoding2[
#                                                                  0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 50, 34)      0           ['learnable_positional_encoding2[
#  da)                                                             0][0]',
# ...

# %% [markdown]
# ## t2

# %%
m10 = get_model_10(window_size=50, pt_cnt=17, num_layers=4, num_heads=16, key_dim=64, value_dim=64)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 50, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 50, 34)      1700        ['input_2[0][0]']
#  _1 (LearnablePositionalEncodin
#  g2)
#
#  multi_head_attention_5 (MultiH  (None, 50, 34)      142370      ['learnable_positional_encoding2_
#  eadAttention)                                                   1[0][0]',
#                                                                   'learnable_positional_encoding2_
#                                                                  1[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 50, 34)      0           ['learnable_positional_encoding2_
#  ambda)                                                          1[0][0]',
# ...

# %%
prediction_m10t2 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(1e-4), num_layers=5, 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, model=m10)
print(prediction_m10t2.shape)
np.save('../results/r7/prediction_m10t2.npy', prediction_m10t2)
# Out:
# coords_corrected_windows.shape: (3000, 50, 17, 2)
# coords_augmented_windows.shape: (51000, 50, 17, 2)
# X min = 0.15, X max = 0.86
# y min = 0.15, y max = 0.86
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 50, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 50, 34)      1700        ['input_2[0][0]']
#  _1 (LearnablePositionalEncodin
#  g2)
#
#  multi_head_attention_5 (MultiH  (None, 50, 34)      142370      ['learnable_positional_encoding2_
#  eadAttention)                                                   1[0][0]',
#                                                                   'learnable_positional_encoding2_
#                                                                  1[0][0]']
#
# ...

# %% [markdown]
# ## t3

# %%
m10 = get_model_10(window_size=50, pt_cnt=17, num_layers=4, num_heads=8, key_dim=32, value_dim=32)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 50, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 50, 34)      1700        ['input_3[0][0]']
#  _2 (LearnablePositionalEncodin
#  g2)
#
#  multi_head_attention_9 (MultiH  (None, 50, 34)      35618       ['learnable_positional_encoding2_
#  eadAttention)                                                   2[0][0]',
#                                                                   'learnable_positional_encoding2_
#                                                                  2[0][0]']
#
#  tf.__operators__.add_18 (TFOpL  (None, 50, 34)      0           ['learnable_positional_encoding2_
#  ambda)                                                          2[0][0]',
# ...

# %%
prediction_m10t3 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(1e-4), num_layers=5, 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, model=m10)
print(prediction_m10t3.shape)
np.save('../results/r7/prediction_m10t3.npy', prediction_m10t3)
# Out:
# coords_corrected_windows.shape: (3000, 50, 17, 2)
# coords_augmented_windows.shape: (51000, 50, 17, 2)
# X min = 0.15, X max = 0.86
# y min = 0.15, y max = 0.86
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 50, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 50, 34)      1700        ['input_3[0][0]']
#  _2 (LearnablePositionalEncodin
#  g2)
#
#  multi_head_attention_9 (MultiH  (None, 50, 34)      35618       ['learnable_positional_encoding2_
#  eadAttention)                                                   2[0][0]',
#                                                                   'learnable_positional_encoding2_
#                                                                  2[0][0]']
#
# ...

# %% [markdown]
# ## t4

# %%
m10 = get_model_10(window_size=50, pt_cnt=17, num_layers=3, num_heads=8, key_dim=16, value_dim=16)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 50, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 50, 34)      1700        ['input_4[0][0]']
#  _3 (LearnablePositionalEncodin
#  g2)
#
#  multi_head_attention_13 (Multi  (None, 50, 34)      17826       ['learnable_positional_encoding2_
#  HeadAttention)                                                  3[0][0]',
#                                                                   'learnable_positional_encoding2_
#                                                                  3[0][0]']
#
#  tf.__operators__.add_26 (TFOpL  (None, 50, 34)      0           ['learnable_positional_encoding2_
#  ambda)                                                          3[0][0]',
# ...

# %%
prediction_m10t4 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(1e-4), num_layers=5, 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, model=m10)
print(prediction_m10t4.shape)
np.save('../results/r7/prediction_m10t4.npy', prediction_m10t4)
# Out:
# coords_corrected_windows.shape: (3000, 50, 17, 2)
# coords_augmented_windows.shape: (51000, 50, 17, 2)
# X min = 0.15, X max = 0.86
# y min = 0.15, y max = 0.86
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 50, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 50, 34)      1700        ['input_4[0][0]']
#  _3 (LearnablePositionalEncodin
#  g2)
#
#  multi_head_attention_13 (Multi  (None, 50, 34)      17826       ['learnable_positional_encoding2_
#  HeadAttention)                                                  3[0][0]',
#                                                                   'learnable_positional_encoding2_
#                                                                  3[0][0]']
#
# ...

# %% [markdown]
# ## t5

# %%
m10 = get_model_10(window_size=50, pt_cnt=17, num_layers=3, num_heads=4, key_dim=8, value_dim=8)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 50, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 50, 34)      1700        ['input_5[0][0]']
#  _4 (LearnablePositionalEncodin
#  g2)
#
#  multi_head_attention_16 (Multi  (None, 50, 34)      4482        ['learnable_positional_encoding2_
#  HeadAttention)                                                  4[0][0]',
#                                                                   'learnable_positional_encoding2_
#                                                                  4[0][0]']
#
#  tf.__operators__.add_32 (TFOpL  (None, 50, 34)      0           ['learnable_positional_encoding2_
#  ambda)                                                          4[0][0]',
# ...

# %%
prediction_m10t5 = run_model_10(epochs=200, batch_size=64, optimizer=Adam(1e-4), num_layers=5, 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, model=m10)
print(prediction_m10t5.shape)
np.save('../results/r7/prediction_m10t5.npy', prediction_m10t5)
# Out:
# coords_corrected_windows.shape: (3000, 50, 17, 2)
# coords_augmented_windows.shape: (51000, 50, 17, 2)
# X min = 0.15, X max = 0.86
# y min = 0.15, y max = 0.86
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 50, 17, 2)]  0           []
#
#  learnable_positional_encoding2  (None, 50, 34)      1700        ['input_5[0][0]']
#  _4 (LearnablePositionalEncodin
#  g2)
#
#  multi_head_attention_16 (Multi  (None, 50, 34)      4482        ['learnable_positional_encoding2_
#  HeadAttention)                                                  4[0][0]',
#                                                                   'learnable_positional_encoding2_
#                                                                  4[0][0]']
#
# ...

# %% [markdown]
# # m11

# %% [markdown]
# ## t1

# %%
m11 = get_model_11(window_size=50, pt_cnt=17, latent_dim=512, num_layers=4)
# tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
prediction_m11t1 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4), 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, model=m11)
print(prediction_m11t1.shape)
np.save('../results/r7/prediction_m11t1.npy', prediction_m11t1)
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_6 (InputLayer)        [(None, 50, 34)]          0
#
#  dense_43 (Dense)            (None, 50, 8192)          286720
#
#  dense_44 (Dense)            (None, 50, 4096)          33558528
#
#  dense_45 (Dense)            (None, 50, 2048)          8390656
#
#  dense_46 (Dense)            (None, 50, 1024)          2098176
#
#  dense_47 (Dense)            (None, 50, 512)           524800
#
#  dense_48 (Dense)            (None, 50, 512)           262656
#
#  dense_49 (Dense)            (None, 50, 1024)          525312
#
#  dense_50 (Dense)            (None, 50, 2048)          2099200
#
#  dense_51 (Dense)            (None, 50, 4096)          8392704
#
#  tf.__operators__.getitem_5   (None, 4096)             0
#  (SlicingOpLambda)
#
#  dense_52 (Dense)            (None, 34)                139298
#
# ...
# Total params: 56,278,050
# ...

# %% [markdown]
# ## t2

# %%
m11 = get_model_11(window_size=50, pt_cnt=17, latent_dim=20, num_layers=4)
# tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
prediction_m11t2 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4), 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, model=m11)
print(prediction_m11t2.shape)
np.save('../results/r7/prediction_m11t2.npy', prediction_m11t2)
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_7 (InputLayer)        [(None, 50, 34)]          0
#
#  dense_53 (Dense)            (None, 50, 320)           11200
#
#  dense_54 (Dense)            (None, 50, 160)           51360
#
#  dense_55 (Dense)            (None, 50, 80)            12880
#
#  dense_56 (Dense)            (None, 50, 40)            3240
#
#  dense_57 (Dense)            (None, 50, 20)            820
#
#  dense_58 (Dense)            (None, 50, 20)            420
#
#  dense_59 (Dense)            (None, 50, 40)            840
#
#  dense_60 (Dense)            (None, 50, 80)            3280
#
#  dense_61 (Dense)            (None, 50, 160)           12960
#
#  tf.__operators__.getitem_6   (None, 160)              0
#  (SlicingOpLambda)
#
#  dense_62 (Dense)            (None, 34)                5474
#
# ...
# Total params: 102,474
# Trainable params: 102,474
# ...

# %% [markdown]
# ## t3

# %%
m11 = get_model_11(window_size=50, pt_cnt=17, latent_dim=128, num_layers=4)
prediction_m11t3 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4), 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, model=m11)
print(prediction_m11t3.shape)
np.save('../results/r7/prediction_m11t3.npy', prediction_m11t3)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 50, 34)]          0
#
#  dense_10 (Dense)            (None, 50, 2048)          71680
#
#  dense_11 (Dense)            (None, 50, 1024)          2098176
#
#  dense_12 (Dense)            (None, 50, 512)           524800
#
#  dense_13 (Dense)            (None, 50, 256)           131328
#
#  dense_14 (Dense)            (None, 50, 128)           32896
#
#  dense_15 (Dense)            (None, 50, 128)           16512
#
#  dense_16 (Dense)            (None, 50, 256)           33024
#
#  dense_17 (Dense)            (None, 50, 512)           131584
#
#  dense_18 (Dense)            (None, 50, 1024)          525312
#
#  tf.__operators__.getitem_1   (None, 1024)             0
#  (SlicingOpLambda)
#
#  dense_19 (Dense)            (None, 34)                34850
#
# ...
# Total params: 3,600,162
# ...

# %% [markdown]
# ## t4

# %%
m11 = get_model_11(window_size=50, pt_cnt=17, latent_dim=64, num_layers=4)
# tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
prediction_m11t4 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4), 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, model=m11)
print(prediction_m11t4.shape)
np.save('../results/r7/prediction_m11t4.npy', prediction_m11t4)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 50, 34)]          0
#
#  dense_20 (Dense)            (None, 50, 1024)          35840
#
#  dense_21 (Dense)            (None, 50, 512)           524800
#
#  dense_22 (Dense)            (None, 50, 256)           131328
#
#  dense_23 (Dense)            (None, 50, 128)           32896
#
#  dense_24 (Dense)            (None, 50, 64)            8256
#
#  dense_25 (Dense)            (None, 50, 64)            4160
#
#  dense_26 (Dense)            (None, 50, 128)           8320
#
#  dense_27 (Dense)            (None, 50, 256)           33024
#
#  dense_28 (Dense)            (None, 50, 512)           131584
#
#  tf.__operators__.getitem_2   (None, 512)              0
#  (SlicingOpLambda)
#
#  dense_29 (Dense)            (None, 34)                17442
#
# ...
# Total params: 927,650
# Trainable params: 927,650
# ...

# %% [markdown]
# ## t5

# %%
m11 = get_model_11(window_size=50, pt_cnt=17, latent_dim=32, num_layers=4)
# tf.keras.utils.plot_model(m11, show_shapes=True, show_layer_names=True, expand_nested=True)
prediction_m11t5 = run_model_11(epochs=200, batch_size=32, optimizer=Adam(1e-4), 
                              window_size=50, dropout_rate=0, swap_rate=0, roll=True, model=m11)
print(prediction_m11t5.shape)
np.save('../results/r7/prediction_m11t5.npy', prediction_m11t5)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_4 (InputLayer)        [(None, 50, 34)]          0
#
#  dense_30 (Dense)            (None, 50, 512)           17920
#
#  dense_31 (Dense)            (None, 50, 256)           131328
#
#  dense_32 (Dense)            (None, 50, 128)           32896
#
#  dense_33 (Dense)            (None, 50, 64)            8256
#
#  dense_34 (Dense)            (None, 50, 32)            2080
#
#  dense_35 (Dense)            (None, 50, 32)            1056
#
#  dense_36 (Dense)            (None, 50, 64)            2112
#
#  dense_37 (Dense)            (None, 50, 128)           8320
#
#  dense_38 (Dense)            (None, 50, 256)           33024
#
#  tf.__operators__.getitem_3   (None, 256)              0
#  (SlicingOpLambda)
#
#  dense_39 (Dense)            (None, 34)                8738
#
# ...
# Total params: 245,730
# Trainable params: 245,730
# ...
