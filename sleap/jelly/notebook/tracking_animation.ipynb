# %%
import sleap
import numpy as np

import sys
sys.path.append('..')
from python.animation import *

# This prevents TensorFlow from allocating all the GPU memory, which leads to issues on
# some GPUs/platforms:
# sleap.disable_preallocation()

# This would hide GPUs from the TensorFlow altogether:
# sleap.use_cpu_onl
# Print some info:
sleap.versions()
sleap.system_summary()
# Out:
# SLEAP: 1.4.1
# TensorFlow: 2.7.0
# Numpy: 1.21.5
# Python: 3.7.12
# OS: Linux-6.8.0-51-generic-x86_64-with-debian-trixie-sid
# GPUs: 2/2 available
#   Device: /physical_device:GPU:0
#          Available: True
#        Initialized: False
#      Memory growth: None
#   Device: /physical_device:GPU:1
#          Available: True
#        Initialized: False
#      Memory growth: None

# %%
# v1_flowmax_track_path = '/home/mingxiao/Desktop/jellyfish/label/multifish/predictions/flowmax-tracking/video_1_flowmax_tracking.slp'
# v1_flowmax_labels = sleap.load_file(v1_flowmax_track_path)
# v1_flowmax_labels

# %%
# c3_labels_path = '/home/mingxiao/Desktop/jellyfish/video/video_1_clips/predictions/predictions/c3_predictions.slp.250120_125305.predictions.slp'
# c3_labels = sleap.load_file(c3_labels_path)

# %%
flowmax_idx = [3]
for i in flowmax_idx:
    flowmax_track_path = f'/home/mingxiao/Desktop/jellyfish/video/video_1_clips/predictions/flowmax-tracking/c{i}_flowmax_tracking.slp'
    print(flowmax_track_path)
    flowmax_labels = sleap.load_file(flowmax_track_path)
    print(flowmax_labels)
    output_path = f'/home/mingxiao/Desktop/animation/c{i}_flowmax_track.mp4'
    get_animation(flowmax_labels, reorder=True, fps=150, output_path=output_path)
# Out:
# /home/mingxiao/Desktop/jellyfish/video/video_1_clips/predictions/flowmax-tracking/c3_flowmax_tracking.slp
# Labels(labeled_frames=0, videos=0, skeletons=0, tracks=0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4089315/3224259868.py in <module>
#       6     print(flowmax_labels)
#       7     output_path = f'/home/mingxiao/Desktop/animation/c{i}_flowmax_track.mp4'
# ----> 8     get_animation(flowmax_labels, reorder=True, fps=150, output_path=output_path)
#
# ~/Desktop/jelly-sleap/sleap/jelly/python/animation.py in get_animation(label, reorder, fps, output_path)
#     109     Get an animation of the tracked points.
#     110     """
# --> 111     frame_cnt, x, y = label.video.shape[:3]
#     112     frame_cnt -= 1  # Skip first frame
#     113     all_tracked_points = get_all_tracked_points(label, reorder)
#
# ~/sleap/sleap/io/dataset.py in video(self)
#     570         """Return the video if there is only a single video in the labels."""
#     571         if len(self.videos) == 0:
# --> 572             raise ValueError("There are no videos in the labels.")
#     573         elif len(self.videos) == 1:
#     574             return self.videos[0]
#
# ValueError: There are no videos in the labels.

# %%
output_path = '/home/mingxiao/Desktop/c3_simplemax_track.mp4'
get_animation(c3_labels, reorder=True, fps=150, output_path=output_path)
# Out:
# Missing point count: 105
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter._run: running command: ffmpeg -f rawvideo -vcodec rawvideo -s 800x800 -pix_fmt rgba -r 150 -loglevel error -i pipe: -vcodec h264 -pix_fmt yuv420p -y /home/mingxiao/Desktop/c3_tracking_v2.mp4
