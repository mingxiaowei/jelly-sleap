# %%
import sleap
import numpy as np

# This prevents TensorFlow from allocating all the GPU memory, which leads to issues on
# some GPUs/platforms:
# sleap.disable_preallocation()

# This would hide GPUs from the TensorFlow altogether:
# sleap.use_cpu_onl
# Print some info:
sleap.versions()
sleap.system_summary()
# Out:
# SLEAP: 1.4.1
# TensorFlow: 2.7.0
# Numpy: 1.21.5
# Python: 3.7.12
# OS: Linux-6.8.0-51-generic-x86_64-with-debian-trixie-sid
# GPUs: 2/2 available
#   Device: /physical_device:GPU:0
#          Available: True
#        Initialized: False
#      Memory growth: None
#   Device: /physical_device:GPU:1
#          Available: True
#        Initialized: False
#      Memory growth: None

# %%
c3_labels_path = '/home/mingxiao/Desktop/jellyfish/video/video_1_clips/predictions/predictions/c3_predictions.slp.250120_125305.predictions.slp'
c3_labels = sleap.load_file(c3_labels_path)

# %%
c3_labels.labeled_frames[0]
# Out:
# LabeledFrame(video=MediaVideo('/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4'), frame_idx=0, instances=17)

# %%
c3_labels.labeled_frames[0].instances
# Out:
# [PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (106.4, 28.5, 1.00)], score=0.91, track=Track(spawned_on=0, name='track_0'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (80.1, 30.7, 1.00)], score=0.94, track=Track(spawned_on=0, name='track_1'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (60.7, 36.8, 1.00)], score=0.90, track=Track(spawned_on=0, name='track_2'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (118.4, 44.5, 1.00)], score=0.95, track=Track(spawned_on=0, name='track_3'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (46.5, 46.5, 1.00)], score=0.93, track=Track(spawned_on=0, name='track_4'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (126.7, 58.6, 1.00)], score=0.90, track=Track(spawned_on=0, name='track_5'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (32.7, 62.1, 1.00)], score=0.85, track=Track(spawned_on=0, name='track_6'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (134.5, 78.7, 1.00)], score=0.89, track=Track(spawned_on=0, name='track_7'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (38.4, 84.6, 1.00)], score=0.95, track=Track(spawned_on=0, name='track_8'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (138.2, 90.2, 1.00)], score=0.82, track=Track(spawned_on=0, name='track_9'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (44.6, 104.1, 1.00)], score=0.88, track=Track(spawned_on=0, name='track_10'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (140.5, 106.3, 1.00)], score=0.91, track=Track(spawned_on=0, name='track_11'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (120.7, 116.6, 1.00)], score=0.92, track=Track(spawned_on=0, name='track_12'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (50.0, 118.2, 1.00)], score=0.88, track=Track(spawned_on=0, name='track_13'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (104.7, 126.2, 1.00)], score=0.91, track=Track(spawned_on=0, name='track_14'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (58.4, 134.6, 1.00)], score=0.91, track=Track(spawned_on=0, name='track_15'), tracking_score=0.00),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=0, points=[tb1_node: (86.4, 134.5, 1.00)], score=0.96, track=Track(spawned_on=0, name='track_16'), tracking_score=0.00)]

# %%
c3_labels.labeled_frames[0].instances[0].points[0].x
# Out:
# 106.39509582519531

# %%
missing_point_cnt = 0
missing_point_frame_idx = []
missing_track_cnt = 0
for lbf in c3_labels.labeled_frames:
    if len(lbf.instances) != 17:
        missing_point_cnt += 1
        missing_point_frame_idx.append(lbf.frame_idx)
    for instance in lbf.instances:
        try:
            assert instance.track is not None
        except:
            missing_track_cnt += 1
print(f"missing_point_cnt: {missing_point_cnt}")
print(f"missing_track_cnt: {missing_track_cnt}")
# Out:
# missing_point_cnt: 81
# missing_track_cnt: 0

# %%
c3_labels.labeled_frames[missing_point_frame_idx[0]].instances
# Out:
# [PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (80.4, 40.4, 1.00)], score=0.94, track=Track(spawned_on=0, name='track_1'), tracking_score=-3.83),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (104.5, 46.4, 1.00)], score=0.71, track=Track(spawned_on=0, name='track_0'), tracking_score=-4.49),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (64.2, 48.2, 1.00)], score=0.91, track=Track(spawned_on=0, name='track_2'), tracking_score=-0.23),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (52.4, 58.1, 1.00)], score=0.87, track=Track(spawned_on=0, name='track_4'), tracking_score=-2.20),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (114.6, 58.3, 0.99)], score=0.87, track=Track(spawned_on=0, name='track_3'), tracking_score=-4.38),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (124.5, 66.4, 1.00)], score=0.86, track=Track(spawned_on=0, name='track_5'), tracking_score=-4.34),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (38.3, 68.1, 0.99)], score=0.90, track=Track(spawned_on=0, name='track_6'), tracking_score=-10.34),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (40.4, 86.6, 1.00)], score=0.95, track=Track(spawned_on=0, name='track_8'), tracking_score=-4.27),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (120.3, 86.3, 1.00)], score=0.85, track=Track(spawned_on=0, name='track_9'), tracking_score=-5.78),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (120.1, 100.4, 1.00)], score=0.67, track=Track(spawned_on=0, name='track_11'), tracking_score=-5.06),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (46.6, 102.3, 1.00)], score=0.84, track=Track(spawned_on=0, name='track_10'), tracking_score=-1.70),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (54.1, 112.1, 1.00)], score=0.87, track=Track(spawned_on=0, name='track_13'), tracking_score=-4.17),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (110.1, 112.3, 1.00)], score=0.81, track=Track(spawned_on=0, name='track_12'), tracking_score=-10.25),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (68.7, 118.5, 1.00)], score=0.76, track=Track(spawned_on=0, name='track_15'), tracking_score=-8.75),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (100.6, 118.5, 1.00)], score=0.85, track=Track(spawned_on=0, name='track_14'), tracking_score=-8.89),
#  PredictedInstance(video=Video(filename=/home/mingxiao/Desktop/jellyfish/video/video_1_clips/full_video_1_c3.mp4, shape=(828, 170, 174, 1), backend=MediaVideo), frame_idx=143, points=[tb1_node: (86.7, 122.7, 1.00)], score=0.91, track=Track(spawned_on=0, name='track_16'), tracking_score=-8.20)]

# %%
c3_labels.skeletons
# Out:
# [Skeleton(name='TB1', description='None', nodes=['tb1_node'], edges=[], symmetries=[])]

# %% [markdown]
# ## interpolate missing point position

# %%
frame_cnt = len(c3_labels.labeled_frames)
instance_cnt = len(c3_labels.labeled_frames[0].instances)
print(frame_cnt, instance_cnt)
all_tracked_points = np.zeros((frame_cnt, instance_cnt, 2))

# populate all_tracked_coords with known coordinates
for lf in c3_labels.labeled_frames:
    for instance in lf.instances:
        track_idx = int(instance.track.name.split('_')[-1])
        all_tracked_points[lf.frame_idx, track_idx] = instance.points_array[0]

# interpolate missing coordinates
for frame_idx in range(frame_cnt):
    for inst_idx in range(instance_cnt):
        if all_tracked_points[frame_idx, inst_idx].sum() == 0:
            if frame_idx == 0:
                prev_frame_idx = frame_idx
                while all_tracked_points[prev_frame_idx, inst_idx].sum() == 0:
                    prev_frame_idx += 1
                next_frame_idx = prev_frame_idx
            else:
                prev_frame_idx = frame_idx - 1
                while all_tracked_points[prev_frame_idx, inst_idx].sum() == 0:
                    prev_frame_idx -= 1
                next_frame_idx = frame_idx
                while all_tracked_points[next_frame_idx, inst_idx].sum() == 0:
                    next_frame_idx += 1
            all_tracked_points[frame_idx, inst_idx] = (all_tracked_points[prev_frame_idx, inst_idx] + all_tracked_points[next_frame_idx, inst_idx]) / 2
# Out:
# 828 17

# %%
video_shape = c3_labels.videos[0].shape

# %%
video_shape
# Out:
# (828, 170, 174, 1)

# %%
# I want to make an animation of 828 frames with canvas size (170, 174). For each frame, I have the 2D coordinates of 17 points available as all_tracked_points, which is a (828, 17, 2) numpy array. I want to plot the points and connect them via edges (first to second, second to third, ..., last to first).

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

# Create figure and axis
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xlim(0, 174)
ax.set_ylim(0, 170)
ax.invert_yaxis()  # Invert y-axis since image coordinates start from top

# Initialize empty line and scatter objects
line, = ax.plot([], [], 'b-', lw=1)  # Line for edges
scat = ax.scatter([], [], c='red', s=30)  # Points

def init():
    line.set_data([], [])
    scat.set_offsets(np.zeros((0, 2)))  # Correct way to initialize empty scatter
    return line, scat

def animate(frame):
    # Get points for current frame
    points = all_tracked_points[frame]  # Shape: (17, 2)
    
    # Add first point to end to close the polygon
    points_closed = np.vstack([points, points[0]])
    
    # Update line (edges)
    line.set_data(points_closed[:, 0], points_closed[:, 1])
    
    # Update scatter (points)
    scat.set_offsets(points)
    
    return line, scat

# Create animation
anim = animation.FuncAnimation(fig, animate, init_func=init, 
                             frames=frame_cnt, interval=50, blit=True)

plt.show()

# Optional: save animation
anim.save('/home/mingxiao/Desktop/tracking.mp4', writer='ffmpeg', fps=150)
# Out:
# INFO:matplotlib.animation:Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# INFO:matplotlib.animation:MovieWriter._run: running command: ffmpeg -f rawvideo -vcodec rawvideo -s 800x800 -pix_fmt rgba -r 150 -loglevel error -i pipe: -vcodec h264 -pix_fmt yuv420p -y /home/mingxiao/Desktop/tracking.mp4

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# Create figure and axis
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xlim(0, 174)
ax.set_ylim(0, 170)

# Initialize empty line and scatter objects
line, = ax.plot([], [], 'b-')  # Line for edges
scat = ax.scatter([], [], c='red', s=50)  # Points

def init():
    line.set_data([], [])
    scat.set_offsets([])
    return line, scat

def animate(frame):
    # Get points for current frame
    points = all_tracked_points[frame] # (17, 2)
    
    # Add first point to end to close the polygon
    points_closed = np.vstack([points, points[0]])
    print(f'points_closed.shape: {points_closed.shape}')
    
    # Update line (edges)
    line.set_data(points_closed[:, 0], points_closed[:, 1])
    
    # Update scatter (points)
    scat.set_offsets(points)
    
    return line, scat

# Create animation
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=frame_cnt, interval=50, blit=True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1583690/1122893389.py in <module>
#      33
#      34 # Create animation
# ---> 35 anim = animation.FuncAnimation(fig, animate, init_func=init, frames=frame_cnt, interval=50, blit=True)
#      36
#      37 plt.show()
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/animation.py in __init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1632         self._save_seq = []
#    1633
# -> 1634         super().__init__(fig, **kwargs)
#    1635
#    1636         # Need to reset the saved seq, since right now it will contain data
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/animation.py in __init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1394         if event_source is None:
#    1395             event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1396         super().__init__(fig, event_source=event_source, *args, **kwargs)
#    1397
#    1398     def _step(self, *args):
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/animation.py in __init__(self, fig, event_source, blit)
#     881                                                       self._stop)
#     882         if self._blit:
# --> 883             self._setup_blit()
#     884
#     885     def __del__(self):
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/animation.py in _setup_blit(self)
#    1195         self._resize_id = self._fig.canvas.mpl_connect('resize_event',
#    1196                                                        self._on_resize)
# -> 1197         self._post_draw(None, self._blit)
#    1198
#    1199     def _on_resize(self, event):
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/animation.py in _post_draw(self, framedata, blit)
#    1148             self._blit_draw(self._drawn_artists)
#    1149         else:
# -> 1150             self._fig.canvas.draw_idle()
#    1151
#    1152     # The rest of the code in this class is to facilitate easy blitting
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2058         if not self._is_idle_drawing:
#    2059             with self._idle_draw_cntx():
# -> 2060                 self.draw(*args, **kwargs)
#    2061
#    2062     @property
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2853             self.stale = False
#    2854
# -> 2855         self.canvas.draw_event(renderer)
#    2856
#    2857     def draw_without_rendering(self):
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_event(self, renderer)
#    1777         s = 'draw_event'
#    1778         event = DrawEvent(s, self, renderer)
# -> 1779         self.callbacks.process(s, event)
#    1780
#    1781     def resize_event(self):
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     290                 except Exception as exc:
#     291                     if self.exception_handler is not None:
# --> 292                         self.exception_handler(exc)
#     293                     else:
#     294                         raise
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     285             if func is not None:
#     286                 try:
# --> 287                     func(*args, **kwargs)
#     288                 # this does not capture KeyboardInterrupt, SystemExit,
#     289                 # and GeneratorExit
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/animation.py in _start(self, *args)
#     905
#     906         # Now do any initial draw
# --> 907         self._init_draw()
#     908
#     909         # Add our callback for stepping the animation and
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/animation.py in _init_draw(self)
#    1696             self._draw_frame(frame_data)
#    1697         else:
# -> 1698             self._drawn_artists = self._init_func()
#    1699             if self._blit:
#    1700                 if self._drawn_artists is None:
#
# /tmp/ipykernel_1583690/1122893389.py in init()
#      13 def init():
#      14     line.set_data([], [])
# ---> 15     scat.set_offsets([])
#      16     return line, scat
#      17
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/matplotlib/collections.py in set_offsets(self, offsets)
#     562             offsets = offsets[None, :]
#     563         self._offsets = np.column_stack(
# --> 564             (np.asarray(self.convert_xunits(offsets[:, 0]), 'float'),
#     565              np.asarray(self.convert_yunits(offsets[:, 1]), 'float')))
#     566         self.stale = True
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
