# %%
from unet_model import *
# from sleap.nn.model import Model
from sleap.nn.architectures import UNet
from sleap.nn.heads import MaskHead

# %%
mask_model = MaskModel(backbone=UNet(), heads=[MaskHead()]).make_model((256, 256, 1))

# %%
tf.keras.utils.plot_model(mask_model, show_shapes=True, expand_nested=True, dpi=64)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/pydot/core.py in create(self, prog, format, encoding)
#    1755                 arguments=arguments,
# -> 1756                 working_dir=tmp_dir,
#    1757             )
#
# ~/micromamba/envs/sleap/lib/python3.7/site-packages/pydot/core.py in call_graphviz(program, arguments, working_dir, **kwargs)
#     139         stdout=subprocess.PIPE,
# --> 140         **kwargs,
#     141     )
#
# ~/micromamba/envs/sleap/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# ...

# %%
mask_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input (InputLayer)             [(None, 256, 256, 1  0           []
#                                 )]
#
#  stack0_enc0_conv0 (Conv2D)     (None, 256, 256, 64  640         ['input[0][0]']
#                                 )
#
#  stack0_enc0_act0_relu (Activat  (None, 256, 256, 64  0          ['stack0_enc0_conv0[0][0]']
#  ion)                           )
#
#  stack0_enc0_conv1 (Conv2D)     (None, 256, 256, 64  36928       ['stack0_enc0_act0_relu[0][0]']
#                                 )
#
#  stack0_enc0_act1_relu (Activat  (None, 256, 256, 64  0          ['stack0_enc0_conv1[0][0]']
#  ion)                           )
#
#  stack0_enc1_pool (MaxPooling2D  (None, 128, 128, 64  0          ['stack0_enc0_act1_relu[0][0]']
#  )                              )
#
# ...
